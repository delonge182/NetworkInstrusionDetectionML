# %%
import pandas as pd
import json as json
import matplotlib.pyplot as plt
import numpy as np

from numpy import array
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Activation


from elasticsearch import Elasticsearch
from elasticsearch import helpers
from sklearn.cluster import KMeans
from pandas.io.json import json_normalize
from scipy.stats import entropy
# Out:
# Using TensorFlow backend.

# %%
def connect_elasticsearch():
    es = Elasticsearch(['https://silabane:PVp5CcJfhoeo6sL2XJkVk8PL@44427d2de.cyberscore.com:443'])
    return es

# %%
def retrieve_data(es, index_name, query, object_filter):
    result_set = es.search(index=index_name, 
                           body=query, 
                           filter_path=object_filter)
    
    return result_set

# %%
host = '172.17.0.2'
port = 9200
ssl = False
auth = 'silabane:PVp5CcJfhoeo6sL2XJkVk8PL'

#es = connect_elasticsearch(host, port, auth, ssl)
es = connect_elasticsearch()

print(es.ping())
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0917 10:45:18.012657 140296047142720 base.py:100] HEAD https://44427d2de.cyberscore.com:443/ [status:403 request:0.092s]
# False

# %%
query_string = {'query':
                {
                    "bool":{
                        "must":[
                            {"match": {'event.action': 'network_flow'}},
                            {"match": {"flow.final": "true"}},
#                             {"match": {"destination.ip": "10.3.6.5"}},
#                             {"match": {"destination.ip": "10.3.8.59"}},
                            {"match": {"destination.ip": "10.3.8.43"}},
                            {"range": {"@timestamp": {"gte": "2019-07-18T04:00:00.000Z",
                                                        "lte":"2019-07-18T09:00:00.000Z"
                                                     }}}
                        ]
                    }
                },
                "from" : 0, 
                "size" : 1,
                "aggs" : {
                    "connection_per_1m" : {
                        "date_histogram" : {
                            "field" : "@timestamp",
                            "interval" : "1m"
                        },
                        "aggs" : {
                            "source_ip" : {
                                "terms" : {
                                    "field" : "source.ip",
                                    "size" : 100
                                },
                                "aggs": {
                                  "destination_ip": {
                                    "terms": {
                                        "field": "destination.ip",
                                        "order": {
                                            "port_count_distinct": "desc"
                                        }
                                    },
                                    "aggs": {
                                        "port_count_distinct": {
                                            "cardinality": {
                                                "field": "destination.port"
                                            }
                                        }
                                    }
                                  }
                                }
                            }
                        }
                    }
                }
               }


object_filter = ''
result = retrieve_data(es, 'packetbeat-*', query_string, object_filter)

# %%
result
# Out:
# {'took': 628,
#  'timed_out': False,
#  '_shards': {'total': 8, 'successful': 8, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 0, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []},
#  'aggregations': {'connection_per_1m': {'buckets': []}}}

# %%
query_string_test = {'query':
                {
                    "bool":{
                        "must":[
                            {"match": {'event.action': 'network_flow'}},
                            {"match": {"flow.final": "true"}},
#                             {"match": {"destination.ip": "10.3.6.5"}},
#                             {"match": {"destination.ip": "10.3.8.123"}},
                            {"match": {"destination.ip": "10.3.8.43"}},
#                             {"match": {"destination.ip": "10.3.8.59"}},
                            {"range": {"@timestamp": {"gte": "2019-07-18T09:00:00.000Z",
#                                                       "lte": "now"
                                                      "lt":"2019-07-18T14:00:00.000Z"
                                                     }}}
                        ]
                    }
                },
                "from" : 0, 
                "size" : 1,
                "aggs" : {
                    "connection_per_1m" : {
                        "date_histogram" : {
                            "field" : "@timestamp",
                            "interval" : "1m"
                        },
                        "aggs" : {
                            "source_ip" : {
                                "terms" : {
                                    "field" : "source.ip",
                                    "size" : 10000
                                },
                                "aggs": {
                                  "destination_ip": {
                                    "terms": {
                                        "field": "destination.ip",
                                        "order": {
                                            "port_count_distinct": "desc"
                                        }
                                    },
                                    "aggs": {
                                        "port_count_distinct": {
                                            "cardinality": {
                                                "field": "destination.port"
                                            }
                                        }
                                    }
                                  }
                                }
                            }
                        }
                    }
                }
               }


object_filter_test = ''
result_test = retrieve_data(es, 'packetbeat-*', query_string_test, object_filter_test)

# %%
flat_aggregate = json_normalize(result['aggregations']['connection_per_1m']['buckets'])

# %%
flat_aggregate_test = json_normalize(result_test['aggregations']['connection_per_1m']['buckets'])

# %%
master_dataframe = pd.DataFrame(columns=['time_bucket', 'source_ip', 'source_ip_count', 
                                         'destination_ip', 'destination_ip_count', 'destination_ip_distinct'])

# %%
master_dataframe_test = pd.DataFrame(columns=['time_bucket', 'source_ip', 'source_ip_count', 
                                         'destination_ip', 'destination_ip_count', 'destination_ip_distinct'])

# %%
for time1 in range(0, len(flat_aggregate)):
    current_df1 = json_normalize(flat_aggregate.iloc[time1, 3])
    for source_idx in range(0, len(current_df1)):
        current_df2 = json_normalize(current_df1['destination_ip.buckets'][source_idx])
        for dest_idx in range(0, len(current_df2)):
            master_idx = len(master_dataframe)
            master_dataframe.loc[master_idx, 'time_bucket'] = flat_aggregate.loc[time1, 'key_as_string']
            master_dataframe.loc[master_idx, 'source_ip'] = current_df1.loc[source_idx, 'key']
            master_dataframe.loc[master_idx, 'source_ip_count'] = current_df1.loc[source_idx, 'doc_count']
            master_dataframe.loc[master_idx, 'destination_ip'] = current_df2.loc[dest_idx, 'key']
            master_dataframe.loc[master_idx, 'destination_ip_count'] = current_df2.loc[dest_idx, 'doc_count']
            master_dataframe.loc[master_idx, 'destination_ip_distinct'] = current_df2.loc[dest_idx, 'port_count_distinct.value']

# %%
for time_test in range(0, len(flat_aggregate_test)):
    current_df1_test = json_normalize(flat_aggregate_test.iloc[time_test, 3])
    for source_idx in range(0, len(current_df1_test)):
        current_df2_test = json_normalize(current_df1_test['destination_ip.buckets'][source_idx])
        for dest_idx_test in range(0, len(current_df2_test)):
            master_idx = len(master_dataframe_test)
            master_dataframe_test.loc[master_idx, 'time_bucket'] = flat_aggregate_test.loc[time_test, 'key_as_string']
            master_dataframe_test.loc[master_idx, 'source_ip'] = current_df1_test.loc[source_idx, 'key']
            master_dataframe_test.loc[master_idx, 'source_ip_count'] = current_df1_test.loc[source_idx, 'doc_count']
            master_dataframe_test.loc[master_idx, 'destination_ip'] = current_df2_test.loc[dest_idx_test, 'key']
            master_dataframe_test.loc[master_idx, 'destination_ip_count'] = current_df2_test.loc[dest_idx_test, 'doc_count']
            master_dataframe_test.loc[master_idx, 'destination_ip_distinct'] = current_df2_test.loc[dest_idx_test, 'port_count_distinct.value']

# %%
master_dataframe['total_connection'] = master_dataframe.groupby(['time_bucket', 'destination_ip'])['destination_ip_distinct'].transform('sum')

# %%
master_dataframe_test['total_connection'] = master_dataframe_test.groupby(['time_bucket', 'destination_ip'])['destination_ip_distinct'].transform('sum')

# %%
time_step_dataframe = master_dataframe.drop_duplicates(subset='time_bucket', keep='first', inplace=False).drop(['source_ip', 'source_ip_count', 'destination_ip','destination_ip_count', 'destination_ip_distinct','total_connection'], axis=1)
destination_dataframe = master_dataframe.drop_duplicates(subset='destination_ip', keep='first', inplace=False).drop(['time_bucket', 'source_ip', 'source_ip_count','destination_ip_count', 'destination_ip_distinct','total_connection'], axis=1)
time_step_dataframe['key_id'] = 1
destination_dataframe['key_id'] = 1

# %%
time_step_dataframe_test = master_dataframe_test.drop_duplicates(subset='time_bucket', keep='first', inplace=False).drop(['source_ip', 'source_ip_count', 'destination_ip','destination_ip_count', 'destination_ip_distinct','total_connection'], axis=1)
destination_dataframe_test = master_dataframe_test.drop_duplicates(subset='destination_ip', keep='first', inplace=False).drop(['time_bucket', 'source_ip', 'source_ip_count','destination_ip_count', 'destination_ip_distinct', 'total_connection'], axis=1)
time_step_dataframe_test['key_id'] = 1
destination_dataframe_test['key_id'] = 1

# %%
joined_df = pd.merge(time_step_dataframe, destination_dataframe, on='key_id').drop('key_id', axis=1)

# %%
joined_df_test = pd.merge(time_step_dataframe_test, destination_dataframe_test, on='key_id').drop('key_id', axis=1)

# %%
joined_df2 = pd.merge(joined_df, master_dataframe, 
                      left_on=['time_bucket', 'destination_ip'], right_on=['time_bucket', 'destination_ip'], how='left')

# %%
joined_df2_test = pd.merge(joined_df_test, master_dataframe_test, 
                      left_on=['time_bucket', 'destination_ip'], right_on=['time_bucket', 'destination_ip'], how='left')

# %%
joined_df2.drop_duplicates(subset=['time_bucket', 'destination_ip'], keep='first', inplace=True)
joined_df2=joined_df2.reset_index(drop=True)
joined_df2.head(5)
# Out:
#                 time_bucket destination_ip  source_ip source_ip_count  \
# 0  2019-07-18T04:00:00.000Z      10.3.8.43  10.3.8.58              77
# 1  2019-07-18T04:01:00.000Z      10.3.8.43  10.3.8.58              62
# 2  2019-07-18T04:02:00.000Z      10.3.8.43  10.3.8.58              62
# 3  2019-07-18T04:03:00.000Z      10.3.8.43  10.3.8.58              78
# 4  2019-07-18T04:04:00.000Z      10.3.8.43  10.3.8.58              70
#
#   destination_ip_count destination_ip_distinct  total_connection
# 0                   77                       1                 1
# 1                   62                       1                 2
# 2                   62                       1                 2
# 3                   78                       1                 2
# 4                   70                       1                 2

# %%
joined_df2_test.drop_duplicates(subset=['time_bucket', 'destination_ip'], keep='first', inplace=True)
joined_df2_test=joined_df2_test.reset_index(drop=True)
joined_df2_test.iloc[40:100]
# Out:
#                  time_bucket destination_ip   source_ip  source_ip_count  \
# 40  2019-07-18T09:40:00.000Z      10.3.8.43   10.3.8.58               66
# 41  2019-07-18T09:41:00.000Z      10.3.8.43   10.3.8.58               61
# 42  2019-07-18T09:42:00.000Z      10.3.8.43   10.3.8.58               62
# 43  2019-07-18T09:43:00.000Z      10.3.8.43   10.3.8.58               78
# 44  2019-07-18T09:44:00.000Z      10.3.8.43  10.3.8.122             6666
# 45  2019-07-18T09:45:00.000Z      10.3.8.43   10.3.8.58               58
# 46  2019-07-18T09:46:00.000Z      10.3.8.43   10.3.8.58               65
# 47  2019-07-18T09:47:00.000Z      10.3.8.43   10.3.8.58               63
# 48  2019-07-18T09:48:00.000Z      10.3.8.43   10.3.8.58               61
# 49  2019-07-18T09:49:00.000Z      10.3.8.43   10.3.8.58               65
# 50  2019-07-18T09:50:00.000Z      10.3.8.43  10.3.8.122               68
# 51  2019-07-18T09:51:00.000Z      10.3.8.43  10.3.8.122              156
# 52  2019-07-18T09:52:00.000Z      10.3.8.43   10.3.8.58               65
# 53  2019-07-18T09:53:00.000Z      10.3.8.43   10.3.8.58               79
# 54  2019-07-18T09:54:00.000Z      10.3.8.43   10.3.8.58               65
# 55  2019-07-18T09:55:00.000Z      10.3.8.43  10.3.8.122              163
# 56  2019-07-18T09:56:00.000Z      10.3.8.43   10.3.8.58               66
# 57  2019-07-18T09:57:00.000Z      10.3.8.43   10.3.8.58               61
# 58  2019-07-18T09:58:00.000Z      10.3.8.43   10.3.8.58               62
# 59  2019-07-18T09:59:00.000Z      10.3.8.43   10.3.8.58               78
# 60  2019-07-18T10:00:00.000Z      10.3.8.43   10.3.8.58               71
# 61  2019-07-18T10:01:00.000Z      10.3.8.43  10.3.8.122              132
# 62  2019-07-18T10:02:00.000Z      10.3.8.43   10.3.8.58               66
# 63  2019-07-18T10:03:00.000Z      10.3.8.43   10.3.8.58               78
# 64  2019-07-18T10:04:00.000Z      10.3.8.43   10.3.8.58               66
# 65  2019-07-18T10:05:00.000Z      10.3.8.43   10.3.8.58               66
# 66  2019-07-18T10:06:00.000Z      10.3.8.43   10.3.8.58               65
# 67  2019-07-18T10:07:00.000Z      10.3.8.43   10.3.8.58               64
# 68  2019-07-18T10:08:00.000Z      10.3.8.43   10.3.8.58               63
# 69  2019-07-18T10:09:00.000Z      10.3.8.43   10.3.8.58               64
# 70  2019-07-18T10:10:00.000Z      10.3.8.43   10.3.8.58               64
# 71  2019-07-18T10:11:00.000Z      10.3.8.43   10.3.8.58               61
# 72  2019-07-18T10:12:00.000Z      10.3.8.43   10.3.8.58               66
# 73  2019-07-18T10:13:00.000Z      10.3.8.43   10.3.8.58               78
# 74  2019-07-18T10:14:00.000Z      10.3.8.43   10.3.8.58               67
# 75  2019-07-18T10:15:00.000Z      10.3.8.43   10.3.8.58               66
# 76  2019-07-18T10:16:00.000Z      10.3.8.43   10.3.8.58               66
# 77  2019-07-18T10:17:00.000Z      10.3.8.43   10.3.8.58               62
# 78  2019-07-18T10:18:00.000Z      10.3.8.43   10.3.8.58               62
# 79  2019-07-18T10:19:00.000Z      10.3.8.43   10.3.8.58               63
# 80  2019-07-18T10:20:00.000Z      10.3.8.43   10.3.8.58               64
# 81  2019-07-18T10:21:00.000Z      10.3.8.43   10.3.8.58               63
# 82  2019-07-18T10:22:00.000Z      10.3.8.43   10.3.8.58               66
# 83  2019-07-18T10:23:00.000Z      10.3.8.43   10.3.8.58               78
# 84  2019-07-18T10:24:00.000Z      10.3.8.43   10.3.8.58               66
# 85  2019-07-18T10:25:00.000Z      10.3.8.43   10.3.8.58               65
# 86  2019-07-18T10:26:00.000Z      10.3.8.43   10.3.8.58               67
# 87  2019-07-18T10:27:00.000Z      10.3.8.43   10.3.8.58               62
# 88  2019-07-18T10:28:00.000Z      10.3.8.43   10.3.8.58               62
# 89  2019-07-18T10:29:00.000Z      10.3.8.43   10.3.8.58               63
# 90  2019-07-18T10:30:00.000Z      10.3.8.43   10.3.8.58               65
# 91  2019-07-18T10:31:00.000Z      10.3.8.43   10.3.8.58               61
# 92  2019-07-18T10:32:00.000Z      10.3.8.43   10.3.8.58               67
# 93  2019-07-18T10:33:00.000Z      10.3.8.43   10.3.8.58               78
# 94  2019-07-18T10:34:00.000Z      10.3.8.43   10.3.8.58               66
# 95  2019-07-18T10:35:00.000Z      10.3.8.43   10.3.8.58               65
# 96  2019-07-18T10:36:00.000Z      10.3.8.43   10.3.8.58               67
# 97  2019-07-18T10:37:00.000Z      10.3.8.43   10.3.8.58               62
# 98  2019-07-18T10:38:00.000Z      10.3.8.43   10.3.8.58               62
# 99  2019-07-18T10:39:00.000Z      10.3.8.43   10.3.8.58               64
#
#     destination_ip_count  destination_ip_distinct  total_connection  \
# 40                    66                        1                 1
# 41                    61                        1                 1
# 42                    62                        1                 1
# 43                    78                        1                 2
# 44                  6666                     4482              4484
# 45                    58                        1                 1
# 46                    65                        1                 2
# 47                    63                        1                 1
# 48                    61                        1                 2
# 49                    65                        1                 1
# 50                    68                        3                 4
# 51                   156                       52                54
# 52                    65                        1                 3
# 53                    79                        1                 4
# 54                    65                        1                 2
# 55                   163                       51                52
# 56                    66                        1                 2
# 57                    61                        1                 2
# 58                    62                        1                 3
# 59                    78                        1                 2
# 60                    71                        1                 2
# 61                   132                       51                52
# 62                    66                        1                 2
# 63                    78                        1                 2
# 64                    66                        1                 1
# 65                    66                        1                 1
# 66                    65                        1                 2
# 67                    64                        1                 1
# 68                    63                        1                 2
# 69                    64                        1                 1
# 70                    64                        1                 1
# 71                    61                        1                 1
# 72                    66                        1                 1
# 73                    78                        1                 2
# 74                    67                        1                 1
# 75                    66                        1                 1
# 76                    66                        1                 2
# 77                    62                        1                 1
# 78                    62                        1                 3
# 79                    63                        1                 1
# 80                    64                        1                 1
# 81                    63                        1                 1
# 82                    66                        1                 1
# 83                    78                        1                 2
# 84                    66                        1                 1
# 85                    65                        1                 1
# 86                    67                        1                 2
# 87                    62                        1                 1
# 88                    62                        1                 2
# 89                    63                        1                 1
# 90                    65                        1                 1
# 91                    61                        1                 1
# 92                    67                        1                 1
# 93                    78                        1                 2
# 94                    66                        1                 1
# 95                    65                        1                 1
# 96                    67                        1                 2
# 97                    62                        1                 1
# 98                    62                        1                 2
# 99                    64                        1                 1
#
#     destination_ip_factor
# 40                      0
# 41                      0
# 42                      0
# 43                      0
# 44                      0
# 45                      0
# 46                      0
# 47                      0
# 48                      0
# 49                      0
# 50                      0
# 51                      0
# 52                      0
# 53                      0
# 54                      0
# 55                      0
# 56                      0
# 57                      0
# 58                      0
# 59                      0
# 60                      0
# 61                      0
# 62                      0
# 63                      0
# 64                      0
# 65                      0
# 66                      0
# 67                      0
# 68                      0
# 69                      0
# 70                      0
# 71                      0
# 72                      0
# 73                      0
# 74                      0
# 75                      0
# 76                      0
# 77                      0
# 78                      0
# 79                      0
# 80                      0
# 81                      0
# 82                      0
# 83                      0
# 84                      0
# 85                      0
# 86                      0
# 87                      0
# 88                      0
# 89                      0
# 90                      0
# 91                      0
# 92                      0
# 93                      0
# 94                      0
# 95                      0
# 96                      0
# 97                      0
# 98                      0
# 99                      0

# %%
# for line1 in joined_df2_test:
#     print (line1)
    
# for index, row in joined_df2_test.iterrows():
#     print(row['time_bucket'], row['source_ip_count'], row['total_connection'])

# %%
joined_df2['destination_ip_factor'] = joined_df2['destination_ip'].factorize()[0]
joined_df2['destination_ip_count'].fillna(0, inplace=True)
joined_df2['destination_ip_distinct'].fillna(0, inplace=True)
joined_df2['source_ip_count'].fillna(0, inplace=True)

# %%
joined_df2_test['destination_ip_factor'] = joined_df2_test['destination_ip'].factorize()[0]
joined_df2_test['destination_ip_count'].fillna(0, inplace=True)
joined_df2_test['destination_ip_distinct'].fillna(0, inplace=True)
joined_df2_test['source_ip_count'].fillna(0, inplace=True)

# %%
# split a univariate sequence into samples
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the sequence
        if end_ix > len(sequence)-1:
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# %% [markdown]
# ## Training

# %%
from numpy import hstack

#raw_seq = joined_df2.iloc[0:, [3,5]]
in_seq1 = array(joined_df2.iloc[0:, 3])
in_seq2 = array(joined_df2.iloc[0:, 6])
in_seq1 = in_seq1.reshape((len(in_seq1), 1))
in_seq2 = in_seq2.reshape((len(in_seq2), 1))
dataset = hstack((in_seq1, in_seq2))

n_steps = 30
X, y = split_sequence(dataset, n_steps)

n_features = 2
X = X.reshape((X.shape[0], X.shape[1], n_features))

model2 = Sequential()
model2.add(LSTM(input_shape=(n_steps, n_features), 
               units = 64, 
               return_sequences = True))
model2.add(Dropout(0.5))
model2.add(LSTM(128))
model2.add(Dropout(0.5))
model2.add(Dense(2))
model2.add(Activation("relu"))
model2.compile(loss = "mape", 
              optimizer = 'RMSprop', metrics=['mae', 'mse'])

model2.fit(X, y, 
          batch_size = 5,
          epochs = 100,
          validation_split = 0.1,
          verbose=1)
# Out:
# W0809 18:11:48.486635 139660286940992 deprecation_wrapper.py:119] From /home/febriantoe/anaconda3/envs/environment1/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0809 18:11:48.504301 139660286940992 deprecation_wrapper.py:119] From /home/febriantoe/anaconda3/envs/environment1/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0809 18:11:48.507008 139660286940992 deprecation_wrapper.py:119] From /home/febriantoe/anaconda3/envs/environment1/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0809 18:11:48.761563 139660286940992 deprecation_wrapper.py:119] From /home/febriantoe/anaconda3/envs/environment1/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0809 18:11:48.853202 139660286940992 deprecation.py:506] From /home/febriantoe/anaconda3/envs/environment1/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0809 18:11:49.107778 139660286940992 deprecation_wrapper.py:119] From /home/febriantoe/anaconda3/envs/environment1/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0809 18:11:49.406921 139660286940992 deprecation.py:323] From /home/febriantoe/anaconda3/envs/environment1/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0809 18:11:50.791531 139660286940992 deprecation_wrapper.py:119] From /home/febriantoe/anaconda3/envs/environment1/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Train on 243 samples, validate on 27 samples
# Epoch 1/100
# 243/243 [==============================] - 8s 33ms/step - loss: 65.4244 - mean_absolute_error: 32.7540 - mean_squared_error: 2129.8923 - val_loss: 66.2906 - val_mean_absolute_error: 32.5289 - val_mean_squared_error: 2101.9160
# Epoch 2/100
# 243/243 [==============================] - 4s 17ms/step - loss: 63.0734 - mean_absolute_error: 32.1894 - mean_squared_error: 2059.3460 - val_loss: 56.9848 - val_mean_absolute_error: 31.8661 - val_mean_squared_error: 2023.7459
# Epoch 3/100
# 243/243 [==============================] - 4s 17ms/step - loss: 60.9577 - mean_absolute_error: 31.1547 - mean_squared_error: 1930.1825 - val_loss: 57.8002 - val_mean_absolute_error: 30.7945 - val_mean_squared_error: 1886.5742
# Epoch 4/100
# 243/243 [==============================] - 4s 17ms/step - loss: 58.9522 - mean_absolute_error: 30.0159 - mean_squared_error: 1791.9625 - val_loss: 55.0051 - val_mean_absolute_error: 29.2624 - val_mean_squared_error: 1706.1791
# Epoch 5/100
# 243/243 [==============================] - 4s 17ms/step - loss: 56.7459 - mean_absolute_error: 28.3178 - mean_squared_error: 1596.5441 - val_loss: 54.3528 - val_mean_absolute_error: 27.8001 - val_mean_squared_error: 1536.6449
# Epoch 6/100
# 243/243 [==============================] - 4s 17ms/step - loss: 52.7382 - mean_absolute_error: 26.4854 - mean_squared_error: 1398.9300 - val_loss: 49.6589 - val_mean_absolute_error: 25.4630 - val_mean_squared_error: 1292.8516
# Epoch 7/100
# 243/243 [==============================] - 4s 17ms/step - loss: 49.5689 - mean_absolute_error: 24.4812 - mean_squared_error: 1196.5548 - val_loss: 43.6065 - val_mean_absolute_error: 23.5591 - val_mean_squared_error: 1109.6445
# Epoch 8/100
# 243/243 [==============================] - 4s 17ms/step - loss: 46.8980 - mean_absolute_error: 22.2167 - mean_squared_error: 987.9861 - val_loss: 46.1628 - val_mean_absolute_error: 21.0277 - val_mean_squared_error: 881.9596
# Epoch 9/100
# 243/243 [==============================] - 4s 18ms/step - loss: 44.0800 - mean_absolute_error: 19.9194 - mean_squared_error: 798.1570 - val_loss: 37.3457 - val_mean_absolute_error: 19.1443 - val_mean_squared_error: 735.1058
# Epoch 10/100
# 243/243 [==============================] - 4s 18ms/step - loss: 40.5753 - mean_absolute_error: 18.1666 - mean_squared_error: 665.9736 - val_loss: 36.4389 - val_mean_absolute_error: 16.9447 - val_mean_squared_error: 575.8912
# Epoch 11/100
# 243/243 [==============================] - 4s 18ms/step - loss: 36.7518 - mean_absolute_error: 15.5697 - mean_squared_error: 494.9477 - val_loss: 32.7400 - val_mean_absolute_error: 14.3014 - val_mean_squared_error: 413.5723
# Epoch 12/100
# 243/243 [==============================] - 4s 18ms/step - loss: 33.3113 - mean_absolute_error: 13.1122 - mean_squared_error: 361.3208 - val_loss: 27.9310 - val_mean_absolute_error: 12.2638 - val_mean_squared_error: 307.0448
# Epoch 13/100
# 243/243 [==============================] - 4s 17ms/step - loss: 29.8993 - mean_absolute_error: 10.7971 - mean_squared_error: 252.5585 - val_loss: 27.6039 - val_mean_absolute_error: 9.5717 - val_mean_squared_error: 190.7810
# Epoch 14/100
# 243/243 [==============================] - 4s 17ms/step - loss: 26.1760 - mean_absolute_error: 8.4693 - mean_squared_error: 167.8230 - val_loss: 21.0960 - val_mean_absolute_error: 7.1057 - val_mean_squared_error: 111.0544
# Epoch 15/100
# 243/243 [==============================] - 4s 17ms/step - loss: 22.9461 - mean_absolute_error: 5.8758 - mean_squared_error: 97.5170 - val_loss: 16.2304 - val_mean_absolute_error: 5.2509 - val_mean_squared_error: 66.8323
# Epoch 16/100
# 243/243 [==============================] - 4s 17ms/step - loss: 21.6054 - mean_absolute_error: 4.9121 - mean_squared_error: 69.3708 - val_loss: 15.5569 - val_mean_absolute_error: 3.6385 - val_mean_squared_error: 39.1192
# Epoch 17/100
# 243/243 [==============================] - 4s 17ms/step - loss: 19.7188 - mean_absolute_error: 4.2536 - mean_squared_error: 52.6721 - val_loss: 12.1858 - val_mean_absolute_error: 2.5911 - val_mean_squared_error: 26.6487
# Epoch 18/100
# 243/243 [==============================] - 4s 17ms/step - loss: 19.5409 - mean_absolute_error: 4.0306 - mean_squared_error: 48.5016 - val_loss: 11.8499 - val_mean_absolute_error: 2.3310 - val_mean_squared_error: 23.1105
# Epoch 19/100
# 243/243 [==============================] - 4s 17ms/step - loss: 17.7432 - mean_absolute_error: 3.8525 - mean_squared_error: 46.1667 - val_loss: 15.2813 - val_mean_absolute_error: 2.3116 - val_mean_squared_error: 18.9951
# Epoch 20/100
# 243/243 [==============================] - 4s 17ms/step - loss: 17.7924 - mean_absolute_error: 3.9929 - mean_squared_error: 44.1622 - val_loss: 16.2387 - val_mean_absolute_error: 2.3355 - val_mean_squared_error: 19.5557
# Epoch 21/100
# 243/243 [==============================] - 4s 18ms/step - loss: 16.3611 - mean_absolute_error: 3.6688 - mean_squared_error: 41.1574 - val_loss: 11.9607 - val_mean_absolute_error: 2.2775 - val_mean_squared_error: 19.6682
# Epoch 22/100
# 243/243 [==============================] - 4s 17ms/step - loss: 17.2114 - mean_absolute_error: 3.9905 - mean_squared_error: 43.9607 - val_loss: 12.5634 - val_mean_absolute_error: 2.3419 - val_mean_squared_error: 17.2749
# Epoch 23/100
# 243/243 [==============================] - 4s 17ms/step - loss: 17.1697 - mean_absolute_error: 3.8691 - mean_squared_error: 43.4551 - val_loss: 12.3144 - val_mean_absolute_error: 2.3146 - val_mean_squared_error: 17.9882
# Epoch 24/100
# 243/243 [==============================] - 4s 17ms/step - loss: 17.1971 - mean_absolute_error: 3.8406 - mean_squared_error: 41.1139 - val_loss: 12.7548 - val_mean_absolute_error: 2.3042 - val_mean_squared_error: 18.9482
# Epoch 25/100
# 243/243 [==============================] - 4s 18ms/step - loss: 16.3645 - mean_absolute_error: 3.7176 - mean_squared_error: 42.5508 - val_loss: 16.2436 - val_mean_absolute_error: 2.4348 - val_mean_squared_error: 16.0153
# Epoch 26/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.4869 - mean_absolute_error: 3.7344 - mean_squared_error: 40.8507 - val_loss: 16.5933 - val_mean_absolute_error: 2.3840 - val_mean_squared_error: 16.9273
# Epoch 27/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.5579 - mean_absolute_error: 3.7185 - mean_squared_error: 39.3473 - val_loss: 14.2319 - val_mean_absolute_error: 2.3622 - val_mean_squared_error: 17.0807
# Epoch 28/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.8514 - mean_absolute_error: 3.8108 - mean_squared_error: 44.8134 - val_loss: 14.5170 - val_mean_absolute_error: 2.3688 - val_mean_squared_error: 16.9757
# Epoch 29/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.5024 - mean_absolute_error: 3.7650 - mean_squared_error: 39.6678 - val_loss: 11.8127 - val_mean_absolute_error: 2.3334 - val_mean_squared_error: 17.3892
# Epoch 30/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.4854 - mean_absolute_error: 3.7130 - mean_squared_error: 39.3983 - val_loss: 13.7892 - val_mean_absolute_error: 2.3868 - val_mean_squared_error: 16.5302
# Epoch 31/100
# 243/243 [==============================] - 4s 17ms/step - loss: 17.0082 - mean_absolute_error: 3.8883 - mean_squared_error: 43.0774 - val_loss: 11.6864 - val_mean_absolute_error: 2.2992 - val_mean_squared_error: 18.5902
# Epoch 32/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.3025 - mean_absolute_error: 3.7526 - mean_squared_error: 39.9200 - val_loss: 12.8910 - val_mean_absolute_error: 2.3410 - val_mean_squared_error: 17.3446
# Epoch 33/100
# 243/243 [==============================] - 4s 17ms/step - loss: 15.9123 - mean_absolute_error: 3.5240 - mean_squared_error: 36.8704 - val_loss: 16.4250 - val_mean_absolute_error: 2.4698 - val_mean_squared_error: 15.6127
# Epoch 34/100
# 243/243 [==============================] - 4s 18ms/step - loss: 16.7510 - mean_absolute_error: 3.8142 - mean_squared_error: 43.2125 - val_loss: 11.5784 - val_mean_absolute_error: 2.2999 - val_mean_squared_error: 18.5022
# Epoch 35/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.4518 - mean_absolute_error: 3.7026 - mean_squared_error: 41.5457 - val_loss: 11.8055 - val_mean_absolute_error: 2.3237 - val_mean_squared_error: 17.6272
# Epoch 36/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.8686 - mean_absolute_error: 3.9987 - mean_squared_error: 47.2651 - val_loss: 14.6775 - val_mean_absolute_error: 2.3900 - val_mean_squared_error: 16.5566
# Epoch 37/100
# 243/243 [==============================] - 4s 16ms/step - loss: 16.6116 - mean_absolute_error: 3.8003 - mean_squared_error: 41.3370 - val_loss: 13.6284 - val_mean_absolute_error: 2.3278 - val_mean_squared_error: 17.7866
# Epoch 38/100
# 243/243 [==============================] - 4s 16ms/step - loss: 15.9385 - mean_absolute_error: 3.6635 - mean_squared_error: 37.6767 - val_loss: 14.2575 - val_mean_absolute_error: 2.3904 - val_mean_squared_error: 16.8555
# Epoch 39/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.0091 - mean_absolute_error: 3.6996 - mean_squared_error: 42.1905 - val_loss: 14.5604 - val_mean_absolute_error: 2.3443 - val_mean_squared_error: 17.5076
# Epoch 40/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.4072 - mean_absolute_error: 3.5866 - mean_squared_error: 37.5218 - val_loss: 12.4205 - val_mean_absolute_error: 2.3855 - val_mean_squared_error: 16.4041
# Epoch 41/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.1087 - mean_absolute_error: 3.6929 - mean_squared_error: 38.2663 - val_loss: 13.2821 - val_mean_absolute_error: 2.3000 - val_mean_squared_error: 18.9345
# Epoch 42/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.0721 - mean_absolute_error: 3.6932 - mean_squared_error: 39.3636 - val_loss: 13.1505 - val_mean_absolute_error: 2.3867 - val_mean_squared_error: 16.6510
# Epoch 43/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.2229 - mean_absolute_error: 3.8520 - mean_squared_error: 42.6548 - val_loss: 14.3804 - val_mean_absolute_error: 2.4348 - val_mean_squared_error: 16.1273
# Epoch 44/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.0576 - mean_absolute_error: 3.6581 - mean_squared_error: 38.4302 - val_loss: 16.4913 - val_mean_absolute_error: 2.4238 - val_mean_squared_error: 16.2150
# Epoch 45/100
# 243/243 [==============================] - 4s 18ms/step - loss: 16.1902 - mean_absolute_error: 3.7633 - mean_squared_error: 40.5219 - val_loss: 12.7225 - val_mean_absolute_error: 2.3958 - val_mean_squared_error: 16.2992
# Epoch 46/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.9634 - mean_absolute_error: 4.0362 - mean_squared_error: 47.2386 - val_loss: 12.6587 - val_mean_absolute_error: 2.3685 - val_mean_squared_error: 16.8949
# Epoch 47/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.1973 - mean_absolute_error: 3.6525 - mean_squared_error: 39.5319 - val_loss: 15.7078 - val_mean_absolute_error: 2.3581 - val_mean_squared_error: 18.1634
# Epoch 48/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.0221 - mean_absolute_error: 3.6980 - mean_squared_error: 40.2043 - val_loss: 14.3339 - val_mean_absolute_error: 2.4898 - val_mean_squared_error: 15.4973
# Epoch 49/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.5145 - mean_absolute_error: 3.7690 - mean_squared_error: 39.5296 - val_loss: 12.1095 - val_mean_absolute_error: 2.5199 - val_mean_squared_error: 15.2575
# Epoch 50/100
# 243/243 [==============================] - 4s 16ms/step - loss: 16.3842 - mean_absolute_error: 3.7979 - mean_squared_error: 40.7182 - val_loss: 11.6633 - val_mean_absolute_error: 2.3801 - val_mean_squared_error: 16.4135
# Epoch 51/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.5175 - mean_absolute_error: 4.0148 - mean_squared_error: 45.7416 - val_loss: 12.6111 - val_mean_absolute_error: 2.3195 - val_mean_squared_error: 17.8518
# Epoch 52/100
# 243/243 [==============================] - 4s 17ms/step - loss: 15.8930 - mean_absolute_error: 3.5551 - mean_squared_error: 34.2309 - val_loss: 13.4590 - val_mean_absolute_error: 2.4510 - val_mean_squared_error: 15.6213
# Epoch 53/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.2477 - mean_absolute_error: 3.8579 - mean_squared_error: 40.6760 - val_loss: 11.5870 - val_mean_absolute_error: 2.3274 - val_mean_squared_error: 17.4989
# Epoch 54/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.1926 - mean_absolute_error: 3.7882 - mean_squared_error: 44.0149 - val_loss: 12.3527 - val_mean_absolute_error: 2.4216 - val_mean_squared_error: 15.9690
# Epoch 55/100
# 243/243 [==============================] - 5s 19ms/step - loss: 15.6539 - mean_absolute_error: 3.6010 - mean_squared_error: 38.2982 - val_loss: 15.8700 - val_mean_absolute_error: 2.4510 - val_mean_squared_error: 15.7876
# Epoch 56/100
# 243/243 [==============================] - 4s 18ms/step - loss: 15.6006 - mean_absolute_error: 3.5002 - mean_squared_error: 35.2963 - val_loss: 16.9940 - val_mean_absolute_error: 2.3747 - val_mean_squared_error: 18.1450
# Epoch 57/100
# 243/243 [==============================] - 5s 19ms/step - loss: 15.5726 - mean_absolute_error: 3.5443 - mean_squared_error: 37.0940 - val_loss: 14.3844 - val_mean_absolute_error: 2.5470 - val_mean_squared_error: 15.2759
# Epoch 58/100
# 243/243 [==============================] - 5s 20ms/step - loss: 16.2415 - mean_absolute_error: 3.7468 - mean_squared_error: 41.1854 - val_loss: 11.6145 - val_mean_absolute_error: 2.4057 - val_mean_squared_error: 16.0555
# Epoch 59/100
# 243/243 [==============================] - 5s 20ms/step - loss: 16.1171 - mean_absolute_error: 3.9087 - mean_squared_error: 42.8791 - val_loss: 15.2547 - val_mean_absolute_error: 2.3659 - val_mean_squared_error: 17.1805
# Epoch 60/100
# 243/243 [==============================] - 5s 19ms/step - loss: 15.9437 - mean_absolute_error: 3.6478 - mean_squared_error: 38.7763 - val_loss: 11.4849 - val_mean_absolute_error: 2.3138 - val_mean_squared_error: 17.8382
# Epoch 61/100
# 243/243 [==============================] - 4s 18ms/step - loss: 16.3431 - mean_absolute_error: 3.8002 - mean_squared_error: 40.3727 - val_loss: 12.5501 - val_mean_absolute_error: 2.3417 - val_mean_squared_error: 17.3232
# Epoch 62/100
# 243/243 [==============================] - 4s 18ms/step - loss: 15.8677 - mean_absolute_error: 3.6929 - mean_squared_error: 40.0640 - val_loss: 12.5255 - val_mean_absolute_error: 2.4261 - val_mean_squared_error: 15.8548
# Epoch 63/100
# 243/243 [==============================] - 4s 17ms/step - loss: 15.9211 - mean_absolute_error: 3.7452 - mean_squared_error: 38.9348 - val_loss: 13.8078 - val_mean_absolute_error: 2.3896 - val_mean_squared_error: 16.4984
# Epoch 64/100
# 243/243 [==============================] - 4s 17ms/step - loss: 15.9009 - mean_absolute_error: 3.7349 - mean_squared_error: 39.0531 - val_loss: 15.1581 - val_mean_absolute_error: 2.3988 - val_mean_squared_error: 16.9382
# Epoch 65/100
# 243/243 [==============================] - 4s 18ms/step - loss: 16.2636 - mean_absolute_error: 3.7867 - mean_squared_error: 41.1950 - val_loss: 13.5344 - val_mean_absolute_error: 2.4085 - val_mean_squared_error: 16.3877
# Epoch 66/100
# 243/243 [==============================] - 4s 18ms/step - loss: 16.1125 - mean_absolute_error: 3.8470 - mean_squared_error: 42.5122 - val_loss: 15.7763 - val_mean_absolute_error: 2.3570 - val_mean_squared_error: 17.4191
# Epoch 67/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.2009 - mean_absolute_error: 3.7963 - mean_squared_error: 41.6493 - val_loss: 11.5853 - val_mean_absolute_error: 2.3955 - val_mean_squared_error: 16.1939
# Epoch 68/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.2397 - mean_absolute_error: 3.7916 - mean_squared_error: 41.5356 - val_loss: 14.6896 - val_mean_absolute_error: 2.3736 - val_mean_squared_error: 16.9070
# Epoch 69/100
# 243/243 [==============================] - 4s 18ms/step - loss: 15.1770 - mean_absolute_error: 3.4619 - mean_squared_error: 34.4061 - val_loss: 14.1416 - val_mean_absolute_error: 2.2998 - val_mean_squared_error: 20.2203
# Epoch 70/100
# 243/243 [==============================] - 4s 18ms/step - loss: 16.7363 - mean_absolute_error: 4.1394 - mean_squared_error: 48.9073 - val_loss: 11.9154 - val_mean_absolute_error: 2.3636 - val_mean_squared_error: 16.7865
# Epoch 71/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.3107 - mean_absolute_error: 3.8955 - mean_squared_error: 44.4932 - val_loss: 13.0289 - val_mean_absolute_error: 2.3551 - val_mean_squared_error: 17.0828
# Epoch 72/100
# 243/243 [==============================] - 4s 16ms/step - loss: 16.6082 - mean_absolute_error: 3.9692 - mean_squared_error: 48.0973 - val_loss: 14.2407 - val_mean_absolute_error: 2.3727 - val_mean_squared_error: 16.8671
# Epoch 73/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.3449 - mean_absolute_error: 3.8868 - mean_squared_error: 45.0099 - val_loss: 11.9120 - val_mean_absolute_error: 2.3899 - val_mean_squared_error: 16.2941
# Epoch 74/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.0376 - mean_absolute_error: 3.8535 - mean_squared_error: 41.4300 - val_loss: 16.2323 - val_mean_absolute_error: 2.4468 - val_mean_squared_error: 15.8667
# Epoch 75/100
# 243/243 [==============================] - 4s 17ms/step - loss: 15.4980 - mean_absolute_error: 3.4439 - mean_squared_error: 35.3737 - val_loss: 13.7728 - val_mean_absolute_error: 2.4058 - val_mean_squared_error: 16.2183
# Epoch 76/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.3465 - mean_absolute_error: 4.0026 - mean_squared_error: 45.5675 - val_loss: 13.8345 - val_mean_absolute_error: 2.4750 - val_mean_squared_error: 15.4403
# Epoch 77/100
# 243/243 [==============================] - 4s 17ms/step - loss: 15.6369 - mean_absolute_error: 3.4822 - mean_squared_error: 35.6057 - val_loss: 12.0009 - val_mean_absolute_error: 2.4142 - val_mean_squared_error: 15.9470
# Epoch 78/100
# 243/243 [==============================] - 4s 16ms/step - loss: 16.2960 - mean_absolute_error: 3.8065 - mean_squared_error: 40.6436 - val_loss: 13.8686 - val_mean_absolute_error: 2.4764 - val_mean_squared_error: 15.4153
# Epoch 79/100
# 243/243 [==============================] - 4s 17ms/step - loss: 15.8946 - mean_absolute_error: 3.7696 - mean_squared_error: 41.7734 - val_loss: 13.2487 - val_mean_absolute_error: 2.4530 - val_mean_squared_error: 15.5683
# Epoch 80/100
# 243/243 [==============================] - 4s 17ms/step - loss: 15.5845 - mean_absolute_error: 3.7133 - mean_squared_error: 38.8274 - val_loss: 12.3344 - val_mean_absolute_error: 2.3496 - val_mean_squared_error: 17.0826
# Epoch 81/100
# 243/243 [==============================] - 4s 17ms/step - loss: 15.7158 - mean_absolute_error: 3.6993 - mean_squared_error: 42.2252 - val_loss: 12.7200 - val_mean_absolute_error: 2.4029 - val_mean_squared_error: 16.1708
# Epoch 82/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.0804 - mean_absolute_error: 3.8518 - mean_squared_error: 43.1142 - val_loss: 12.5787 - val_mean_absolute_error: 2.3651 - val_mean_squared_error: 16.8289
# Epoch 83/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.1651 - mean_absolute_error: 3.8097 - mean_squared_error: 41.0650 - val_loss: 11.5149 - val_mean_absolute_error: 2.3591 - val_mean_squared_error: 16.8109
# Epoch 84/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.1498 - mean_absolute_error: 3.9462 - mean_squared_error: 46.6213 - val_loss: 16.0739 - val_mean_absolute_error: 2.4617 - val_mean_squared_error: 15.6828
# Epoch 85/100
# 243/243 [==============================] - 4s 17ms/step - loss: 15.9186 - mean_absolute_error: 3.5611 - mean_squared_error: 34.6630 - val_loss: 14.6356 - val_mean_absolute_error: 2.4075 - val_mean_squared_error: 16.2958
# Epoch 86/100
# 243/243 [==============================] - 4s 17ms/step - loss: 15.7250 - mean_absolute_error: 3.6070 - mean_squared_error: 36.4407 - val_loss: 11.4145 - val_mean_absolute_error: 2.3056 - val_mean_squared_error: 18.1851
# Epoch 87/100
# 243/243 [==============================] - 4s 17ms/step - loss: 15.3396 - mean_absolute_error: 3.6137 - mean_squared_error: 37.5798 - val_loss: 11.5243 - val_mean_absolute_error: 2.3599 - val_mean_squared_error: 16.8468
# Epoch 88/100
# 243/243 [==============================] - 4s 17ms/step - loss: 15.8603 - mean_absolute_error: 3.7741 - mean_squared_error: 41.5844 - val_loss: 12.1017 - val_mean_absolute_error: 2.3666 - val_mean_squared_error: 16.8001
# Epoch 89/100
# 243/243 [==============================] - 4s 17ms/step - loss: 14.9575 - mean_absolute_error: 3.4200 - mean_squared_error: 35.6624 - val_loss: 11.7343 - val_mean_absolute_error: 2.3865 - val_mean_squared_error: 16.3741
# Epoch 90/100
# 243/243 [==============================] - 4s 17ms/step - loss: 14.9976 - mean_absolute_error: 3.4949 - mean_squared_error: 34.1605 - val_loss: 13.5631 - val_mean_absolute_error: 2.2862 - val_mean_squared_error: 20.8604
# Epoch 91/100
# 243/243 [==============================] - 4s 17ms/step - loss: 15.7107 - mean_absolute_error: 3.7360 - mean_squared_error: 40.3889 - val_loss: 12.1201 - val_mean_absolute_error: 2.3164 - val_mean_squared_error: 17.8685
# Epoch 92/100
# 243/243 [==============================] - 4s 17ms/step - loss: 15.8273 - mean_absolute_error: 3.7335 - mean_squared_error: 39.1617 - val_loss: 13.2428 - val_mean_absolute_error: 2.4804 - val_mean_squared_error: 15.3792
# Epoch 93/100
# 243/243 [==============================] - 4s 17ms/step - loss: 15.9733 - mean_absolute_error: 3.6516 - mean_squared_error: 39.8874 - val_loss: 12.8075 - val_mean_absolute_error: 2.3977 - val_mean_squared_error: 16.2527
# Epoch 94/100
# 243/243 [==============================] - 4s 17ms/step - loss: 15.3250 - mean_absolute_error: 3.5327 - mean_squared_error: 34.6671 - val_loss: 12.8615 - val_mean_absolute_error: 2.3655 - val_mean_squared_error: 16.8229
# Epoch 95/100
# 243/243 [==============================] - 4s 18ms/step - loss: 15.7575 - mean_absolute_error: 3.6954 - mean_squared_error: 40.3706 - val_loss: 12.0916 - val_mean_absolute_error: 2.3091 - val_mean_squared_error: 18.3480
# Epoch 96/100
# 243/243 [==============================] - 4s 17ms/step - loss: 15.5656 - mean_absolute_error: 3.6578 - mean_squared_error: 38.8881 - val_loss: 11.4157 - val_mean_absolute_error: 2.3209 - val_mean_squared_error: 17.5823
# Epoch 97/100
# 243/243 [==============================] - 4s 17ms/step - loss: 16.0899 - mean_absolute_error: 3.9673 - mean_squared_error: 44.9073 - val_loss: 11.4062 - val_mean_absolute_error: 2.2784 - val_mean_squared_error: 19.4497
# Epoch 98/100
# 243/243 [==============================] - 4s 17ms/step - loss: 14.9974 - mean_absolute_error: 3.4129 - mean_squared_error: 34.6988 - val_loss: 13.4772 - val_mean_absolute_error: 2.3923 - val_mean_squared_error: 16.3884
# Epoch 99/100
# 243/243 [==============================] - 4s 17ms/step - loss: 15.7487 - mean_absolute_error: 3.7166 - mean_squared_error: 40.4214 - val_loss: 15.2131 - val_mean_absolute_error: 2.5412 - val_mean_squared_error: 15.2261
# Epoch 100/100
# 243/243 [==============================] - 4s 17ms/step - loss: 15.2574 - mean_absolute_error: 3.5482 - mean_squared_error: 35.4620 - val_loss: 12.5167 - val_mean_absolute_error: 2.4178 - val_mean_squared_error: 16.0795

# %%
model2.save("model2.h5")

# %%
model2.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 30, 64)            17152
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 64)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 128)               98816
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# _________________________________________________________________
# activation_1 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 116,226
# Trainable params: 116,226
# Non-trainable params: 0
# _________________________________________________________________

# %%
# define input sequence
raw_seq = joined_df2.iloc[0:, [3,5]]
# choose a number of time steps
n_steps = 12
# split into samples
X, y = split_sequence(raw_seq, n_steps)
# reshape from [samples, timesteps] into [samples, timesteps, features]
n_features = 1
X = X.reshape((X.shape[0], X.shape[1], n_features))
# define model
model = Sequential()
model.add(LSTM(64, activation='relu', return_sequences=False, input_shape=(n_steps, n_features)))
model.add(Dropout(0.5))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
# fit model
model.fit(X, y, epochs=50, verbose=1)

# %% [markdown]
# ## Prediction

# %%
# x_test = array(joined_df2_test.iloc[540:600, [3,5]])
# len(joined_df2_test)
# in_seq1
# in_seq2
# joined_df2.head(2)
x_input

# %%
x_input = array(joined_df2_test.iloc[0:30, [3,6]])
#x_input = array([1,2, 3, 4, 5])
x_input = x_input.reshape((1, n_steps, n_features))
yhat = model2.predict(x_input, verbose=1)
print(yhat)
# Out:
# 1/1 [==============================] - 0s 459ms/step
# [[64.98155    0.9790584]]

# %%
# joined_df2.head()
# joined_df2_test.head()
joined_df2_test.iloc[31, [3,6]]
# Out:
# source_ip_count     61
# total_connection     1
# Name: 31, dtype: object

# %%
# joined_df2_test.iloc[150:, [0,3,5,6,7,8,9]].head()
joined_df2_test.iloc[0:5, [3,5]]

# %%
import urllib.request

predicted_index = 0
for i in range(predicted_index, (len(joined_df2_test) - 60) ):
    x_input = array(joined_df2_test.iloc[i:(i+60), [3,6]])
    x_input = x_input.reshape((1, n_steps, n_features))
    yhat = model2.predict(x_input, verbose=1)
    print(str(yhat[0][1]) + ' - ' + str(joined_df2_test.iloc[i+60, 6]))
    if(joined_df2_test.iloc[i+60, 6] > (yhat[0][1] + 10)):
        contents = urllib.request.urlopen('http://canarytokens.com/articles/l2xdnv3bbs6y8jhz6ysf7bmso/contact.php').read()
        print('port scan detected!! ' + joined_df2_test.iloc[i+60, 0])

# %%
import json
import requests

predicted_index = 0
for i in range(predicted_index, (len(joined_df2_test) - 30) ):
    x_input = array(joined_df2_test.iloc[i:(i+30), [3,6]])
    x_input = x_input.reshape((1, n_steps, n_features))
    yhat = model2.predict(x_input, verbose=1)
    print(str(yhat[0][1]) + ' - ' + str(joined_df2_test.iloc[i+30, 6]))
    if(joined_df2_test.iloc[i+30, 6] > (yhat[0][1] + 10)):
        warning_text = {'text': "Possible threat occured. time: " + joined_df2_test.iloc[i+30, 0] 
                +"; source ip: " + joined_df2_test.iloc[i+30, 2]
                +"; destination ip: " + joined_df2_test.iloc[i+30, 1]}

        response = requests.post(
            'https://hooks.slack.com/services/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', 
            data=json.dumps(warning_text),
            headers={'Content-Type': 'application/json'}
        )
        
        
        print('port scan detected!! ' + joined_df2_test.iloc[i+30, 0])
# Out:
# 1/1 [==============================] - 0s 8ms/step
# 0.9790584 - 1
# 1/1 [==============================] - 0s 9ms/step
# 0.97784543 - 1
# 1/1 [==============================] - 0s 16ms/step
# 0.97899354 - 1
# 1/1 [==============================] - 0s 36ms/step
# 0.9786235 - 2
# 1/1 [==============================] - 0s 12ms/step
# 0.97361 - 1
# 1/1 [==============================] - 0s 12ms/step
# 0.9780468 - 1
# 1/1 [==============================] - 0s 13ms/step
# 0.97908807 - 2
# 1/1 [==============================] - 0s 13ms/step
# 0.9747767 - 1
# 1/1 [==============================] - 0s 12ms/step
# 0.97955066 - 2
# 1/1 [==============================] - 0s 12ms/step
# 0.97607327 - 1
# 1/1 [==============================] - 0s 26ms/step
# 0.9792707 - 1
# 1/1 [==============================] - 0s 17ms/step
# 0.97780395 - 1
# 1/1 [==============================] - 0s 21ms/step
# 0.97899693 - 1
# 1/1 [==============================] - 0s 23ms/step
# 0.9786236 - 2
# 1/1 [==============================] - 0s 12ms/step
# 0.97360843 - 4484
# port scan detected!! 2019-07-18T09:44:00.000Z
# 1/1 [==============================] - 0s 15ms/step
# 0.9705677 - 1
# 1/1 [==============================] - 0s 48ms/step
# 0.9800837 - 2
# 1/1 [==============================] - 0s 18ms/step
# 0.974934 - 1
# 1/1 [==============================] - 0s 35ms/step
# 0.9790897 - 2
# 1/1 [==============================] - 0s 25ms/step
# 0.9764568 - 1
# 1/1 [==============================] - 0s 21ms/step
# 0.978567 - 4
# 1/1 [==============================] - 0s 23ms/step
# 0.9722599 - 54
# port scan detected!! 2019-07-18T09:51:00.000Z
# 1/1 [==============================] - 0s 17ms/step
# 0.96937245 - 3
# 1/1 [==============================] - 0s 77ms/step
# 0.97632366 - 4
# 1/1 [==============================] - 0s 29ms/step
# 0.97164845 - 2
# 1/1 [==============================] - 0s 44ms/step
# 0.9774621 - 52
# port scan detected!! 2019-07-18T09:55:00.000Z
# 1/1 [==============================] - 0s 10ms/step
# 0.96899223 - 2
# 1/1 [==============================] - 0s 38ms/step
# 0.97830564 - 2
# 1/1 [==============================] - 0s 36ms/step
# 0.976866 - 3
# 1/1 [==============================] - 0s 26ms/step
# 0.97471863 - 2
# 1/1 [==============================] - 0s 33ms/step
# 0.97463137 - 2
# 1/1 [==============================] - 0s 25ms/step
# 0.97564745 - 52
# port scan detected!! 2019-07-18T10:01:00.000Z
# 1/1 [==============================] - 0s 8ms/step
# 0.96935296 - 2
# 1/1 [==============================] - 0s 13ms/step
# 0.9783598 - 2
# 1/1 [==============================] - 0s 28ms/step
# 0.9738259 - 1
# 1/1 [==============================] - 0s 15ms/step
# 0.97898173 - 1
# 1/1 [==============================] - 0s 22ms/step
# 0.97794163 - 2
# 1/1 [==============================] - 0s 17ms/step
# 0.9759233 - 1
# 1/1 [==============================] - 0s 17ms/step
# 0.9789729 - 2
# 1/1 [==============================] - 0s 37ms/step
# 0.9761759 - 1
# 1/1 [==============================] - 0s 33ms/step
# 0.9788904 - 1
# 1/1 [==============================] - 0s 37ms/step
# 0.9782768 - 1
# 1/1 [==============================] - 0s 22ms/step
# 0.97889364 - 1
# 1/1 [==============================] - 0s 29ms/step
# 0.97788185 - 2
# 1/1 [==============================] - 0s 24ms/step
# 0.9738447 - 1
# 1/1 [==============================] - 0s 45ms/step
# 0.97880095 - 1
# 1/1 [==============================] - 0s 27ms/step
# 0.9779602 - 2
# 1/1 [==============================] - 0s 45ms/step
# 0.9757229 - 1
# 1/1 [==============================] - 0s 18ms/step
# 0.97938985 - 3
# 1/1 [==============================] - 0s 33ms/step
# 0.97426933 - 1
# 1/1 [==============================] - 0s 25ms/step
# 0.9795396 - 1
# 1/1 [==============================] - 0s 20ms/step
# 0.9781965 - 1
# 1/1 [==============================] - 0s 11ms/step
# 0.9785276 - 1
# 1/1 [==============================] - 0s 28ms/step
# 0.9779352 - 2
# 1/1 [==============================] - 0s 30ms/step
# 0.9737265 - 1
# 1/1 [==============================] - 0s 29ms/step
# 0.9790185 - 1
# 1/1 [==============================] - 0s 28ms/step
# 0.9781105 - 2
# 1/1 [==============================] - 0s 13ms/step
# 0.9754975 - 1
# 1/1 [==============================] - 0s 17ms/step
# 0.9794395 - 2
# 1/1 [==============================] - 0s 10ms/step
# 0.9762874 - 1
# 1/1 [==============================] - 0s 11ms/step
# 0.97902596 - 1
# 1/1 [==============================] - 0s 12ms/step
# 0.9780589 - 1
# 1/1 [==============================] - 0s 9ms/step
# 0.9789646 - 1
# 1/1 [==============================] - 0s 21ms/step
# 0.97765416 - 2
# 1/1 [==============================] - 0s 17ms/step
# 0.9737783 - 1
# 1/1 [==============================] - 0s 15ms/step
# 0.9789962 - 1
# 1/1 [==============================] - 0s 10ms/step
# 0.97810996 - 2
# 1/1 [==============================] - 0s 14ms/step
# 0.9754998 - 1
# 1/1 [==============================] - 0s 9ms/step
# 0.97942764 - 2
# 1/1 [==============================] - 0s 12ms/step
# 0.97627246 - 1
# 1/1 [==============================] - 0s 15ms/step
# 0.97884566 - 1
# 1/1 [==============================] - 0s 31ms/step
# 0.9784693 - 1
# 1/1 [==============================] - 0s 19ms/step
# 0.9784899 - 1
# 1/1 [==============================] - 0s 24ms/step
# 0.9779351 - 2
# 1/1 [==============================] - 0s 17ms/step
# 0.9738681 - 1
# 1/1 [==============================] - 0s 14ms/step
# 0.9789762 - 1
# 1/1 [==============================] - 0s 14ms/step
# 0.97791725 - 2
# 1/1 [==============================] - 0s 15ms/step
# 0.9757183 - 1
# 1/1 [==============================] - 0s 12ms/step
# 0.979386 - 2
# 1/1 [==============================] - 0s 16ms/step
# 0.9760859 - 1
# 1/1 [==============================] - 0s 14ms/step
# 0.97888625 - 1
# 1/1 [==============================] - 0s 22ms/step
# 0.97827405 - 1
# 1/1 [==============================] - 0s 19ms/step
# 0.9787232 - 1
# 1/1 [==============================] - 0s 12ms/step
# 0.9778909 - 2
# 1/1 [==============================] - 0s 28ms/step
# 0.9737387 - 1
# 1/1 [==============================] - 0s 28ms/step
# 0.97899944 - 1
# 1/1 [==============================] - 0s 9ms/step
# 0.9779173 - 2
# 1/1 [==============================] - 0s 12ms/step
# 0.9757206 - 1
# 1/1 [==============================] - 0s 16ms/step
# 0.9793838 - 2
# 1/1 [==============================] - 0s 17ms/step
# 0.9764644 - 1
# 1/1 [==============================] - 0s 13ms/step
# 0.9759162 - 1
# 1/1 [==============================] - 0s 21ms/step
# 0.9775169 - 1
# 1/1 [==============================] - 0s 10ms/step
# 0.9789402 - 1
# 1/1 [==============================] - 0s 14ms/step
# 0.97766507 - 2
# 1/1 [==============================] - 0s 11ms/step
# 0.9737739 - 1
# 1/1 [==============================] - 0s 19ms/step
# 0.9791878 - 1
# 1/1 [==============================] - 0s 10ms/step
# 0.97768307 - 2
# 1/1 [==============================] - 0s 11ms/step
# 0.97576153 - 1
# 1/1 [==============================] - 0s 9ms/step
# 0.9789942 - 2
# 1/1 [==============================] - 0s 25ms/step
# 0.97634846 - 2
# 1/1 [==============================] - 0s 13ms/step
# 0.97653496 - 1
# 1/1 [==============================] - 0s 13ms/step
# 0.97887325 - 1
# 1/1 [==============================] - 0s 16ms/step
# 0.9786579 - 1
# 1/1 [==============================] - 0s 11ms/step
# 0.9780796 - 2
# 1/1 [==============================] - 0s 10ms/step
# 0.97371334 - 1
# 1/1 [==============================] - 0s 28ms/step
# 0.9790044 - 1
# 1/1 [==============================] - 0s 23ms/step
# 0.9779183 - 2
# 1/1 [==============================] - 0s 9ms/step
# 0.9755358 - 38
# port scan detected!! 2019-07-18T11:17:00.000Z
# 1/1 [==============================] - 0s 15ms/step
# 0.9689876 - 33
# port scan detected!! 2019-07-18T11:18:00.000Z
# 1/1 [==============================] - 0s 20ms/step
# 0.96955323 - 55
# port scan detected!! 2019-07-18T11:19:00.000Z
# 1/1 [==============================] - 0s 13ms/step
# 0.9700486 - 66
# port scan detected!! 2019-07-18T11:20:00.000Z
# 1/1 [==============================] - 0s 11ms/step
# 0.97041154 - 56
# port scan detected!! 2019-07-18T11:21:00.000Z
# 1/1 [==============================] - 0s 9ms/step
# 0.9702703 - 80
# port scan detected!! 2019-07-18T11:22:00.000Z
# 1/1 [==============================] - 0s 6ms/step
# 0.970388 - 86
# port scan detected!! 2019-07-18T11:23:00.000Z
# 1/1 [==============================] - 0s 9ms/step
# 0.97043604 - 91
# port scan detected!! 2019-07-18T11:24:00.000Z
# 1/1 [==============================] - 0s 15ms/step
# 0.97045094 - 99
# port scan detected!! 2019-07-18T11:25:00.000Z
# 1/1 [==============================] - 0s 6ms/step
# 0.9703063 - 88
# port scan detected!! 2019-07-18T11:26:00.000Z
# 1/1 [==============================] - 0s 6ms/step
# 0.97007245 - 76
# port scan detected!! 2019-07-18T11:27:00.000Z
# 1/1 [==============================] - 0s 8ms/step
# 0.9699414 - 78
# port scan detected!! 2019-07-18T11:28:00.000Z
# 1/1 [==============================] - 0s 19ms/step
# 0.9699952 - 85
# port scan detected!! 2019-07-18T11:29:00.000Z
# 1/1 [==============================] - 0s 12ms/step
# 0.96996963 - 81
# port scan detected!! 2019-07-18T11:30:00.000Z
# 1/1 [==============================] - 0s 13ms/step
# 0.9699756 - 119
# port scan detected!! 2019-07-18T11:31:00.000Z
# 1/1 [==============================] - 0s 11ms/step
# 0.9693338 - 1
# 1/1 [==============================] - 0s 10ms/step
# 0.98087955 - 2
# 1/1 [==============================] - 0s 28ms/step
# 0.97328573 - 1
# 1/1 [==============================] - 0s 15ms/step
# 0.9790791 - 1
# 1/1 [==============================] - 0s 12ms/step
# 0.97797453 - 2
# 1/1 [==============================] - 0s 16ms/step
# 0.975758 - 1
# 1/1 [==============================] - 0s 28ms/step
# 0.97961175 - 2
# 1/1 [==============================] - 0s 12ms/step
# 0.97627366 - 1
# 1/1 [==============================] - 0s 23ms/step
# 0.9786843 - 1
# 1/1 [==============================] - 0s 13ms/step
# 0.97833884 - 1
# 1/1 [==============================] - 0s 21ms/step
# 0.9787391 - 1
# 1/1 [==============================] - 0s 17ms/step
# 0.9779095 - 2
# 1/1 [==============================] - 0s 24ms/step
# 0.9737571 - 1
# 1/1 [==============================] - 0s 23ms/step
# 0.9792088 - 1
# 1/1 [==============================] - 0s 24ms/step
# 0.97767943 - 2
# 1/1 [==============================] - 0s 23ms/step
# 0.9757704 - 1
# 1/1 [==============================] - 0s 26ms/step
# 0.9793562 - 2
# 1/1 [==============================] - 0s 30ms/step
# 0.9762336 - 1
# 1/1 [==============================] - 0s 26ms/step
# 0.9789928 - 4
# 1/1 [==============================] - 0s 21ms/step
# 0.9726427 - 1
# 1/1 [==============================] - 0s 22ms/step
# 0.9800638 - 1
# 1/1 [==============================] - 0s 12ms/step
# 0.977492 - 2
# 1/1 [==============================] - 0s 18ms/step
# 0.9738743 - 1
# 1/1 [==============================] - 0s 27ms/step
# 0.978953 - 1
# 1/1 [==============================] - 0s 23ms/step
# 0.9778827 - 2
# 1/1 [==============================] - 0s 15ms/step
# 0.9755034 - 1
# 1/1 [==============================] - 0s 14ms/step
# 0.9795722 - 2
# 1/1 [==============================] - 0s 23ms/step
# 0.9762052 - 1
# 1/1 [==============================] - 0s 12ms/step
# 0.97577244 - 1
# 1/1 [==============================] - 0s 18ms/step
# 0.977774 - 1
# 1/1 [==============================] - 0s 29ms/step
# 0.9787022 - 1
# 1/1 [==============================] - 0s 21ms/step
# 0.9779029 - 2
# 1/1 [==============================] - 0s 11ms/step
# 0.9737372 - 1
# 1/1 [==============================] - 0s 15ms/step
# 0.9789991 - 1
# 1/1 [==============================] - 0s 13ms/step
# 0.9779143 - 2
# 1/1 [==============================] - 0s 10ms/step
# 0.97571844 - 1
# 1/1 [==============================] - 0s 12ms/step
# 0.97899926 - 2
# 1/1 [==============================] - 0s 16ms/step
# 0.9763515 - 1
# 1/1 [==============================] - 0s 24ms/step
# 0.9788392 - 1
# 1/1 [==============================] - 0s 19ms/step
# 0.97827625 - 1
# 1/1 [==============================] - 0s 12ms/step
# 0.9789177 - 1
# 1/1 [==============================] - 0s 12ms/step
# 0.9778504 - 2
# 1/1 [==============================] - 0s 6ms/step
# 0.97374374 - 1
# 1/1 [==============================] - 0s 15ms/step
# 0.9788088 - 1
# 1/1 [==============================] - 0s 15ms/step
# 0.9781488 - 2
# 1/1 [==============================] - 0s 28ms/step
# 0.97549236 - 1
# 1/1 [==============================] - 0s 11ms/step
# 0.97942555 - 3
# 1/1 [==============================] - 0s 8ms/step
# 0.97425663 - 1
# 1/1 [==============================] - 0s 8ms/step
# 0.9795471 - 1
# 1/1 [==============================] - 0s 11ms/step
# 0.97701955 - 1
# 1/1 [==============================] - 0s 10ms/step
# 0.9791578 - 1
# 1/1 [==============================] - 0s 8ms/step
# 0.97763973 - 2
# 1/1 [==============================] - 0s 9ms/step
# 0.9737785 - 1
# 1/1 [==============================] - 0s 11ms/step
# 0.9789996 - 1
# 1/1 [==============================] - 0s 17ms/step
# 0.9781104 - 2
# 1/1 [==============================] - 0s 15ms/step
# 0.9754948 - 1
# 1/1 [==============================] - 0s 17ms/step
# 0.97944194 - 2
# 1/1 [==============================] - 0s 18ms/step
# 0.97629976 - 1
# 1/1 [==============================] - 0s 7ms/step
# 0.9788565 - 1
# 1/1 [==============================] - 0s 10ms/step
# 0.97847235 - 41
# port scan detected!! 2019-07-18T12:31:00.000Z
# 1/1 [==============================] - 0s 42ms/step
# 0.9684091 - 40
# port scan detected!! 2019-07-18T12:32:00.000Z
# 1/1 [==============================] - 0s 17ms/step
# 0.9702435 - 65
# port scan detected!! 2019-07-18T12:33:00.000Z
# 1/1 [==============================] - 0s 9ms/step
# 0.97027415 - 68
# port scan detected!! 2019-07-18T12:34:00.000Z
# 1/1 [==============================] - 0s 18ms/step
# 0.96974033 - 64
# port scan detected!! 2019-07-18T12:35:00.000Z
# 1/1 [==============================] - 0s 18ms/step
# 0.96978503 - 64
# port scan detected!! 2019-07-18T12:36:00.000Z
# 1/1 [==============================] - 0s 8ms/step
# 0.97003984 - 63
# port scan detected!! 2019-07-18T12:37:00.000Z
# 1/1 [==============================] - 0s 15ms/step
# 0.97024 - 64
# port scan detected!! 2019-07-18T12:38:00.000Z
# 1/1 [==============================] - 0s 18ms/step
# 0.9701488 - 63
# port scan detected!! 2019-07-18T12:39:00.000Z
# 1/1 [==============================] - 0s 19ms/step
# 0.97025985 - 91
# port scan detected!! 2019-07-18T12:40:00.000Z
# 1/1 [==============================] - 0s 8ms/step
# 0.9696126 - 65
# port scan detected!! 2019-07-18T12:41:00.000Z
# 1/1 [==============================] - 0s 9ms/step
# 0.969958 - 73
# port scan detected!! 2019-07-18T12:42:00.000Z
# 1/1 [==============================] - 0s 18ms/step
# 0.9699309 - 73
# port scan detected!! 2019-07-18T12:43:00.000Z
# 1/1 [==============================] - 0s 9ms/step
# 0.9699361 - 73
# port scan detected!! 2019-07-18T12:44:00.000Z
# 1/1 [==============================] - 0s 13ms/step
# 0.9699241 - 74
# port scan detected!! 2019-07-18T12:45:00.000Z
# 1/1 [==============================] - 0s 8ms/step
# 0.96989566 - 73
# port scan detected!! 2019-07-18T12:46:00.000Z
# 1/1 [==============================] - 0s 9ms/step
# 0.9698996 - 71
# port scan detected!! 2019-07-18T12:47:00.000Z
# 1/1 [==============================] - 0s 8ms/step
# 0.96996367 - 72
# port scan detected!! 2019-07-18T12:48:00.000Z
# 1/1 [==============================] - 0s 13ms/step
# 0.96993595 - 57
# port scan detected!! 2019-07-18T12:49:00.000Z
# 1/1 [==============================] - 0s 18ms/step
# 0.969996 - 1
# 1/1 [==============================] - 0s 29ms/step
# 0.98087704 - 1
# 1/1 [==============================] - 0s 34ms/step
# 0.9789554 - 1
# 1/1 [==============================] - 0s 29ms/step
# 0.978002 - 2
# 1/1 [==============================] - 0s 30ms/step
# 0.9733015 - 1
# 1/1 [==============================] - 0s 33ms/step
# 0.98001117 - 1
# 1/1 [==============================] - 0s 13ms/step
# 0.9769165 - 2
# 1/1 [==============================] - 0s 13ms/step
# 0.97677845 - 1
# 1/1 [==============================] - 0s 25ms/step
# 0.97912014 - 2
# 1/1 [==============================] - 0s 20ms/step
# 0.9767688 - 1
# 1/1 [==============================] - 0s 37ms/step
# 0.9753611 - 1
# 1/1 [==============================] - 0s 19ms/step
# 0.9782448 - 1
# 1/1 [==============================] - 0s 28ms/step
# 0.9786339 - 1
# 1/1 [==============================] - 0s 12ms/step
# 0.97813994 - 2
# 1/1 [==============================] - 0s 17ms/step
# 0.9729013 - 1
# 1/1 [==============================] - 0s 37ms/step
# 0.98015386 - 1
# 1/1 [==============================] - 0s 16ms/step
# 0.9769719 - 2
# 1/1 [==============================] - 0s 17ms/step
# 0.97665006 - 1
# 1/1 [==============================] - 0s 30ms/step
# 0.978847 - 2
# 1/1 [==============================] - 0s 10ms/step
# 0.97643983 - 1
# 1/1 [==============================] - 0s 31ms/step
# 0.97894406 - 1
# 1/1 [==============================] - 0s 26ms/step
# 0.9782258 - 1
# 1/1 [==============================] - 0s 12ms/step
# 0.9786589 - 1
# 1/1 [==============================] - 0s 11ms/step
# 0.9780076 - 2
# 1/1 [==============================] - 0s 27ms/step
# 0.9806594 - 1
# 1/1 [==============================] - 0s 18ms/step
# 0.98403466 - 1
# 1/1 [==============================] - 0s 30ms/step
# 0.98324805 - 1
# 1/1 [==============================] - 0s 12ms/step
# 0.9838536 - 1
# 1/1 [==============================] - 0s 12ms/step
# 0.9835909 - 2
# 1/1 [==============================] - 0s 12ms/step
# 0.98174626 - 1
# 1/1 [==============================] - 0s 12ms/step
# 0.98347455 - 1

# %%
if response.status_code != 200:
    raise ValueError(
        'Request to slack returned an error %s, the response is:\n%s'
        % (response.status_code, response.text)
    )
    
    
resp = requests.post('http://www.mywebsite.com/user', data=userdata)

# %%
for i in range(predicted_index, len(joined_df2_test)):
    print(joined_df2_test.iloc[(i-60):i, [3,5]])

# %%
joined_df2.sort_values(ascending=False, by='destination_ip_distinct')

# %%
joined_df2.loc[(joined_df2['time_bucket'] == '2019-07-02T19:46:00.000Z')]

# %%
len(joined_df2.loc[joined_df2['time_bucket'] == '2019-07-02T19:45:00.000Z'])

# %%
list_destination = list(dict.fromkeys(master_dataframe['destination_ip'].tolist()))

# %%
joined_df2.describe()

# %%
joined_df2.columns

# %%
for ts in flat_aggregate.iloc[0, 0]:
    destination_flat = json_normalize(ts)
    print(destination_flat)

# %%
yhat[0][1] + 10
