# %%
import networkx as netx

import pandas as pd
import json as json
import numpy as np

from elasticsearch import Elasticsearch
from elasticsearch import helpers

from pandas.io.json import json_normalize

# %%
def connect_elasticsearch():
    es = Elasticsearch(['https://silabane:PVp5CcJfhoeo6sL2XJkVk8PL@44427d2de.cyberscore.com:443'])
    return es

# %%
def retrieve_data(es, index_name, query, object_filter):
    result_set = es.search(index=index_name, 
                           body=query, 
                           filter_path=object_filter)
    
    return result_set

# %%
es = connect_elasticsearch()

print(es.ping())
# Out:
# False

# %%
query_string = {
    "query": { 
    "bool": { 
      "must_not": [
          { "match": { "dns.question.etld_plus_one" : "internal.xq"}}
      ]
    }
  }, 
    "from" : 0, 
    "size" : 10000
}
#query_string = {"from" : 0, "size" : 60000}
object_filter = ['hits.hits._source.@timestamp', 
                 'hits.hits._source.agent.hostname',
                 'hits.hits._source.source.ip',
                 'hits.hits._source.destination.ip',
                 'hits.hits._source.domain',
                 'hits.hits._source.sub_domain',
                 'hits.hits._source.dns.question.etld_plus_one'
                ]
result = retrieve_data(es, 'packetbeat-*', query_string, object_filter)

# %%
flat_result = json_normalize(result['hits']['hits'])

# %%
flat_result
# Out:
#             _source.@timestamp _source.agent.hostname _source.destination.ip  \
# 0     2019-09-02T16:57:22.600Z               LT-00056          191.232.139.2
# 1     2019-09-02T16:57:22.822Z               LT-00056          104.72.160.57
# 2     2019-09-02T16:57:22.910Z               LT-00056          40.69.216.251
# 3     2019-09-02T16:57:23.036Z               LT-00056         184.86.208.210
# 4     2019-09-02T16:57:23.299Z               LT-00056         184.86.208.210
# 5     2019-09-02T16:57:23.375Z               LT-00056         93.184.221.240
# 6     2019-09-02T16:57:23.591Z               LT-00056         184.86.208.210
# 7     2019-09-02T16:57:23.603Z               LT-00056          40.77.226.250
# 8     2019-09-02T16:57:23.378Z               LT-00056         93.184.221.240
# 9     2019-09-02T16:57:23.823Z               LT-00056         184.86.208.210
# 10    2019-09-02T16:57:24.044Z               LT-00056            13.107.4.50
# 11    2019-09-02T16:57:24.689Z               LT-00056         184.86.208.210
# 12    2019-09-02T16:57:24.789Z               LT-00056         205.185.216.42
# 13    2019-09-02T16:57:24.807Z               LT-00056          191.232.139.2
# 14    2019-09-02T16:57:24.834Z               LT-00056         184.86.208.210
# 15    2019-09-02T16:57:25.065Z               LT-00056         184.86.208.210
# 16    2019-09-02T16:57:25.148Z               LT-00056         205.185.216.42
# 17    2019-09-02T16:57:25.153Z               LT-00056         184.86.208.210
# 18    2019-09-02T16:57:26.213Z               LT-00056          40.77.226.250
# 19    2019-09-02T16:57:26.466Z               LT-00056         52.155.169.137
# 20    2019-09-02T16:57:26.542Z               LT-00056            13.107.4.52
# 21    2019-09-02T16:57:26.625Z               LT-00056            13.107.4.52
# 22    2019-09-02T16:57:26.669Z               LT-00056            13.107.4.52
# 23    2019-09-02T16:57:26.918Z               LT-00056         184.86.208.210
# 24    2019-09-02T16:57:27.008Z               LT-00056         184.86.208.210
# 25    2019-09-02T16:57:27.044Z               LT-00056         173.222.211.40
# 26    2019-09-02T16:57:26.917Z               LT-00056           51.143.111.7
# 27    2019-09-02T16:57:09.094Z               LT-00056            13.107.4.52
# 28    2019-09-02T16:57:09.392Z               LT-00056            13.107.4.52
# 29    2019-09-02T16:57:09.477Z               LT-00056           13.68.93.109
# ...                        ...                    ...                    ...
# 9970  2019-09-02T17:26:10.016Z               LT-00056         192.168.202.33
# 9971  2019-09-02T17:26:10.016Z               LT-00056           2.22.146.106
