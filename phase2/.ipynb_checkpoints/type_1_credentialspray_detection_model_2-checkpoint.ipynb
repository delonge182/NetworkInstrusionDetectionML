# %%
import pandas as pd
import json as json
import numpy as np

from elasticsearch import Elasticsearch
from elasticsearch import helpers

from pandas.io.json import json_normalize

import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder

import re

# %%
def connect_elasticsearch():
    es = Elasticsearch(['https://silabane:PVp5CcJfhoeo6sL2XJkVk8PL@44427d2de.cyberscore.com:443'])
    return es

# %%
def retrieve_data(es, index_name, query, object_filter):
    result_set = es.search(index=index_name, 
                           body=query, 
                           filter_path=object_filter)
    
    return result_set

# %%
def scan_data(es, index_name, query):
    scan_result = helpers.scan(es,
        query=query,
        index=index_name
    )
    return scan_result

# %%
def extract_date(x):
    result = re.findall("[0-9][0-9][0-9][0-9][0-9][0-9] [0-2][0-9]:[0-6][0-9]:[0-6][0-9]", x)
    if result:
        return result[0].split(' ')[0]
    else:
        return ''

# %%
def extract_time(x):
    result = re.findall("[0-9][0-9][0-9][0-9][0-9][0-9] [0-2][0-9]:[0-6][0-9]:[0-6][0-9]", x)
    if result:
        return result[0].split(' ')[1]
    else:
        return ''

# %%
es = connect_elasticsearch()

print(es.ping())

# %%
query_string = {
  "query": {
    "bool": {
      "must": [
                { "range": { "@timestamp": {"gte": "2019-10-22T07:00:00.000Z", 
                                            "lt":"2019-10-22T19:00:00.000Z" }}}
#           ,
#                 { "match": { "message" : "connect"}}
            ],
      "must_not": [
          { "match": { "message": "Close stmt"}},
          { "match": { "message": "quit"}},
          { "match": { "message": "select"}},
          { "match": { "message": "Execute\tset session sql_mode"}},
          { "match": { "message": "Query\tuse"}}
      ]
    }
  }
#     ,
#     "from" : 0, 
#     "size" : 10000
}

object_filter = ['hits.hits._id', 
                 'hits.hits._source.@timestamp',
                 'hits.hits._source.agent.hostname',
                 'hits.hits._source.message',
#                  'hits.hits._source.domain',
#                  'hits.hits._source.sub_domain',
#                  'hits.hits._source.dns.question.etld_plus_one',
                 'aggregations'
                ]

# object_filter = ""

# result = retrieve_data(es, 'filebeat-*', query_string, object_filter)
result = scan_data(es, 'filebeat-*', query_string)

# %%
####### only if using scan
list_result = list(result)

# %%
temp1_df = pd.DataFrame(list_result)['_source']

# %%
# temp1_df
# df_scan_result = json_normalize(temp1_df)
df_scan_result.to_csv(r'data/scan_filebeat_2019-10-22_1.csv')

# %%
flat_result = pd.read_csv('data/scan_filebeat_2019-10-22_1.csv', index_col=0)
flat_result.head()
# Out:
#                  @timestamp  @version                    agent.ephemeral_id  \
# 0  2019-10-22T08:22:20.267Z         1  e88a8bcb-b56c-4d71-b2c6-64813af8be5e
# 1  2019-10-22T08:22:21.155Z         1  e88a8bcb-b56c-4d71-b2c6-64813af8be5e
# 2  2019-10-22T08:22:21.197Z         1  e88a8bcb-b56c-4d71-b2c6-64813af8be5e
# 3  2019-10-22T08:22:22.378Z         1  e88a8bcb-b56c-4d71-b2c6-64813af8be5e
# 4  2019-10-22T08:22:22.380Z         1  e88a8bcb-b56c-4d71-b2c6-64813af8be5e
#
#   agent.hostname                              agent.id agent.type  \
# 0    t-dock-db-1  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat
# 1    t-dock-db-1  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat
# 2    t-dock-db-1  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat
# 3    t-dock-db-1  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat
# 4    t-dock-db-1  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat
#
#   agent.version ecs.version host.architecture  host.containerized  ...  \
# 0         7.4.0       1.1.0            x86_64               False  ...
# 1         7.4.0       1.1.0            x86_64               False  ...
# 2         7.4.0       1.1.0            x86_64               False  ...
# 3         7.4.0       1.1.0            x86_64               False  ...
# 4         7.4.0       1.1.0            x86_64               False  ...
#
#   host.os.family     host.os.kernel host.os.name host.os.platform  \
# 0         debian  4.4.0-165-generic       Ubuntu           ubuntu
# 1         debian  4.4.0-165-generic       Ubuntu           ubuntu
# 2         debian  4.4.0-165-generic       Ubuntu           ubuntu
# 3         debian  4.4.0-165-generic       Ubuntu           ubuntu
# 4         debian  4.4.0-165-generic       Ubuntu           ubuntu
#
#               host.os.version input.type             log.file.path log.offset  \
# 0  16.04.6 LTS (Xenial Xerus)        log  /var/log/mysql/mysql.log  373252550
# 1  16.04.6 LTS (Xenial Xerus)        log  /var/log/mysql/mysql.log  373324161
# 2  16.04.6 LTS (Xenial Xerus)        log  /var/log/mysql/mysql.log  373382754
# 3  16.04.6 LTS (Xenial Xerus)        log  /var/log/mysql/mysql.log  373554904
# 4  16.04.6 LTS (Xenial Xerus)        log  /var/log/mysql/mysql.log  373558446
#
#                                              message  \
# 0  \t\t17480 Connect\trapierapi@10.3.8.9 as anony...
# 1  \t\t17481 Connect\trapierapi@10.3.8.9 as anony...
# 2  \t\t17482 Connect\trapierapi@10.3.8.9 as anony...
# 3  \t\t17504 Connect\trapierapi@10.3.8.9 as anony...
# 4  \t\t17505 Connect\trapierapi@10.3.8.9 as anony...
#
#                                   tags
# 0  ['beats_input_codec_plain_applied']
# 1  ['beats_input_codec_plain_applied']
# 2  ['beats_input_codec_plain_applied']
# 3  ['beats_input_codec_plain_applied']
# 4  ['beats_input_codec_plain_applied']
#
# [5 rows x 24 columns]

# %%
# flat_result = json_normalize(result['hits']['hits'])


## for scan data only
flat_result = df_scan_result

# %%
flat_result['_id'].count()

# %%
flat_result.info()

# %%
import re

test_string1 = '191016 15:13:14 613454 Connect administrator@10.3.255.61 as anonymous on mypassword'

re.sub("[0-9][0-9][0-9][0-9][0-9][0-9] [0-2][0-9]:[0-6][0-9]:[0-6][0-9] ", '', test_string1)
# flat_result['_source.message'].map(lambda x: x.replace('\t\t','')) #split('Connect\t')

# %%
# flat_result.head()
# flat_result['_source.message'].map(lambda x: x.replace('\t\t','').split(' ', 1)[0])

# flat_result['_source.message'].map(lambda x: re.sub("[0-9][0-9][0-9][0-9][0-9][0-9] [0-2][0-9]:[0-6][0-9]:[0-6][0-9]\t", '\t\t', x))

# %%
# flat_result.loc[flat_result['_source.message'].str.find('select') >= 0, 'message1']
# flat_result.loc[flat_result['event'] == 'connect', 'message1'].map(lambda x: x.split('@', 1)[1].split(' ', 1)[0])

# flat_result.loc[flat_result['event'] != 'connect', 'user'] = flat_result.loc[flat_result['event'] != 'connect', 'session_id'].map(lambda x: flat_result.loc[(flat_result['session_id'] == x) & (flat_result['event'] == 'connect'), 'user'])

# flat_result.loc[flat_result['event'] != 'connect', 'session_id'].map(lambda x: flat_result.loc[(flat_result['session_id'] == x) & (flat_result['event'] == 'connect'), 'user'].to_string().split('    ', 1)[-1])

# flat_result.loc[(flat_result['session'] == x), 'user']

# flat_result.loc[(flat_result['message'].str.find('Connect') >= 0), ['date', 'event']].groupby(['date','event'])['event'].value_counts()

# flat_result.loc[(flat_result['message'].str.find('Connect') >= 0) & (flat_result['date'] == '') , ['message', 'date']]

# %%
flat_result['date'] = flat_result['message'].map(lambda x: extract_date(x))
flat_result.loc[flat_result['date'] != '', 'hour'] = flat_result.loc[flat_result['date'] != '', 'message'].map(lambda x: extract_time(x).split(':')[0])
flat_result.loc[flat_result['date'] != '', 'minute'] = flat_result.loc[flat_result['date'] != '', 'message'].map(lambda x: extract_time(x).split(':')[1])
flat_result.loc[flat_result['date'] != '', 'second'] = flat_result.loc[flat_result['date'] != '', 'message'].map(lambda x: extract_time(x).split(':')[2])

# %%
flat_result['message'] = flat_result['message'].map(
    lambda x: re.sub("[0-9][0-9][0-9][0-9][0-9][0-9] [0-2][0-9]:[0-6][0-9]:[0-6][0-9]\t", '\t\t', x))

flat_result['session_id'] = flat_result['message'].map(lambda x: x.replace('\t\t','').split(' ', 1)[0])

flat_result.loc[flat_result['message'].str.find('Connect') >= 0, 'message1'] = flat_result.loc[flat_result['message'].str.find('Connect') >= 0, 'message'].map(lambda x: x.split('Connect\t')[-1])
flat_result.loc[(flat_result['message'].str.find('Connect') >= 0) & (flat_result['message'].str.find('Connect\tAccess denied') < 0), 'event'] = 'connect' 
flat_result.loc[(flat_result['message'].str.find('Connect\tAccess denied') >= 0), 'event'] = 'connect_failed_notif' 


flat_result.loc[flat_result['message'].str.find('select') >= 0, 'message1'] = 'select'
flat_result.loc[flat_result['message'].str.find('select') >= 0, 'event'] = 'select'

flat_result.loc[(flat_result['message'].str.find('Connect') < 0) & 
                (flat_result['message'].str.find('select') < 0), 'message1'] = 'other'
flat_result.loc[(flat_result['message'].str.find('Connect') < 0) & 
                (flat_result['message'].str.find('select') < 0), 'event'] = 'other'


flat_result.loc[(flat_result['event'] == 'connect') | (flat_result['event'] == 'connect_failed_notif'), 'user'] = flat_result.loc[(flat_result['event'] == 'connect') | (flat_result['event'] == 'connect_failed_notif'), 'message1'].map(lambda x: x.split('@', 1)[0])
flat_result.loc[(flat_result['event'] == 'connect') | (flat_result['event'] == 'connect_failed_notif'), 'from'] = flat_result.loc[(flat_result['event'] == 'connect') | (flat_result['event'] == 'connect_failed_notif'), 'message1'].map(lambda x: x.split('@', 1)[1].split(' ', 1)[0])

flat_result.loc[flat_result['message1'].str.find("Access denied") >= 0, 'login_status'] = 'failed'
for index, row in flat_result.loc[flat_result['login_status'] == 'failed'].iterrows():
    flat_result.loc[(flat_result['session_id'] == row['session_id']), 'login_status'] = 'failed'
flat_result['login_status'].fillna('successful', inplace=True)


flat_result.loc[flat_result['event'] != 'connect', 'user'] = flat_result.loc[flat_result['event'] != 'connect', 'session_id'].map(lambda x: flat_result.loc[(flat_result['session_id'] == x) & (flat_result['event'] == 'connect'), 'user'].to_string().split('    ', 1)[-1])

# %% [markdown]
# ### Drop connect event without datetime
# #### Because it was from long time ago and is not used anymore (duplicate session_id from the past)

# %%
flat_result.drop(index=flat_result.loc[(flat_result['date'] == '') & (flat_result['event'] != 'connect_failed_notif') ].index, inplace=True)
flat_result.reset_index()
# flat_result.loc[(flat_result['date'] == '') & (flat_result['event'] != 'connect_failed_notif')]
# Out:
#          index                @timestamp  @version  \
# 0            6  2019-10-22T08:22:22.385Z         1
# 1            9  2019-10-22T08:22:22.387Z         1
# 2           10  2019-10-22T08:22:22.388Z         1
# 3           11  2019-10-22T08:22:22.388Z         1
# 4           14  2019-10-22T08:22:22.391Z         1
# 5           15  2019-10-22T08:22:22.392Z         1
# 6           18  2019-10-22T08:22:22.393Z         1
# 7           39  2019-10-22T08:22:14.760Z         1
# 8           41  2019-10-22T08:22:17.540Z         1
# 9           44  2019-10-22T08:22:17.542Z         1
# 10          45  2019-10-22T08:22:17.543Z         1
# 11          47  2019-10-22T08:22:17.539Z         1
# 12          56  2019-10-22T08:22:20.204Z         1
# 13          58  2019-10-22T08:22:20.205Z         1
# 14          63  2019-10-22T08:22:20.207Z         1
# 15          65  2019-10-22T08:22:20.188Z         1
# 16          69  2019-10-22T08:22:20.209Z         1
# 17          74  2019-10-22T08:22:20.201Z         1
# 18          76  2019-10-22T08:22:20.210Z         1
# 19          79  2019-10-22T08:22:20.212Z         1
# 20          85  2019-10-22T08:22:20.219Z         1
# 21          86  2019-10-22T08:22:20.220Z         1
# 22          88  2019-10-22T08:22:20.223Z         1
# 23          92  2019-10-22T08:22:20.225Z         1
# 24          93  2019-10-22T08:22:20.226Z         1
# 25          94  2019-10-22T08:22:20.228Z         1
# 26         103  2019-10-22T08:22:17.947Z         1
# 27         104  2019-10-22T08:22:17.947Z         1
# 28         105  2019-10-22T08:22:17.947Z         1
# 29         107  2019-10-22T08:22:17.947Z         1
# ...        ...                       ...       ...
# 298788  888417  2019-10-22T16:19:19.335Z         1
# 298789  888422  2019-10-22T16:19:19.337Z         1
# 298790  888424  2019-10-22T16:19:19.337Z         1
# 298791  888427  2019-10-22T16:19:20.339Z         1
# 298792  888429  2019-10-22T16:19:20.340Z         1
# 298793  888431  2019-10-22T16:19:21.340Z         1
# 298794  888433  2019-10-22T16:19:23.346Z         1
# 298795  888435  2019-10-22T16:19:24.348Z         1
# 298796  888439  2019-10-22T16:19:25.349Z         1
# 298797  888440  2019-10-22T16:19:26.351Z         1
# 298798  888441  2019-10-22T16:21:14.520Z         1
# 298799  888443  2019-10-22T16:21:15.521Z         1
# 298800  888445  2019-10-22T16:21:16.521Z         1
# 298801  888447  2019-10-22T16:21:17.522Z         1
# 298802  888450  2019-10-22T16:21:18.523Z         1
# 298803  888452  2019-10-22T16:21:19.524Z         1
# 298804  888459  2019-10-22T16:21:23.528Z         1
# 298805  888460  2019-10-22T16:21:23.529Z         1
# 298806  888462  2019-10-22T16:21:24.530Z         1
# 298807  888464  2019-10-22T16:21:25.539Z         1
# 298808  888465  2019-10-22T16:21:25.538Z         1
# 298809  888467  2019-10-22T16:21:28.540Z         1
# 298810  888468  2019-10-22T16:21:28.541Z         1
# 298811  888469  2019-10-22T16:21:28.541Z         1
# 298812  888470  2019-10-22T16:21:29.541Z         1
# 298813  888471  2019-10-22T16:21:32.542Z         1
# 298814  888472  2019-10-22T16:21:32.543Z         1
# 298815  888473  2019-10-22T16:21:32.543Z         1
# 298816  888474  2019-10-22T16:21:33.545Z         1
# 298817  888476  2019-10-22T16:21:36.546Z         1
#
#                           agent.ephemeral_id agent.hostname  \
# 0       e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 1       e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 2       e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 3       e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 4       e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 5       e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 6       e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 7       e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 8       e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 9       e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 10      e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 11      e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 12      e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 13      e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 14      e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 15      e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 16      e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 17      e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 18      e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 19      e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 20      e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 21      e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 22      e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 23      e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 24      e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 25      e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 26      e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 27      e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 28      e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 29      e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# ...                                      ...            ...
# 298788  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 298789  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 298790  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 298791  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 298792  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 298793  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 298794  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 298795  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 298796  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 298797  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 298798  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 298799  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 298800  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 298801  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 298802  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 298803  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 298804  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 298805  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 298806  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 298807  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 298808  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 298809  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 298810  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 298811  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 298812  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 298813  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 298814  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 298815  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 298816  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
# 298817  e88a8bcb-b56c-4d71-b2c6-64813af8be5e    t-dock-db-1
#
#                                     agent.id agent.type agent.version  \
# 0       ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 1       ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 2       ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 3       ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 4       ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 5       ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 6       ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 7       ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 8       ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 9       ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 10      ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 11      ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 12      ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 13      ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 14      ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 15      ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 16      ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 17      ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 18      ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 19      ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 20      ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 21      ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 22      ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 23      ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 24      ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 25      ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 26      ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 27      ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 28      ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 29      ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# ...                                      ...        ...           ...
# 298788  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 298789  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 298790  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 298791  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 298792  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 298793  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 298794  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 298795  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 298796  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 298797  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 298798  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 298799  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 298800  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 298801  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 298802  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 298803  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 298804  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 298805  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 298806  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 298807  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 298808  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 298809  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 298810  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 298811  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 298812  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 298813  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 298814  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 298815  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 298816  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
# 298817  ecb8cb71-6c39-4d43-a036-70c07b48bc42   filebeat         7.4.0
#
#        ecs.version host.architecture  ...    date hour minute second  \
# 0            1.1.0            x86_64  ...  191010   15     40     02
# 1            1.1.0            x86_64  ...  191010   15     40     03
# 2            1.1.0            x86_64  ...  191010   15     40     04
# 3            1.1.0            x86_64  ...  191010   15     40     06
# 4            1.1.0            x86_64  ...  191010   15     40     08
# 5            1.1.0            x86_64  ...  191010   15     40     11
# 6            1.1.0            x86_64  ...  191010   15     40     14
# 7            1.1.0            x86_64  ...  191010   15     37     59
# 8            1.1.0            x86_64  ...  191010   15     38     01
# 9            1.1.0            x86_64  ...  191010   15     38     03
# 10           1.1.0            x86_64  ...  191010   15     38     04
# 11           1.1.0            x86_64  ...  191010   15     38     00
# 12           1.1.0            x86_64  ...  191010   15     39     23
# 13           1.1.0            x86_64  ...  191010   15     39     24
# 14           1.1.0            x86_64  ...  191010   15     39     28
# 15           1.1.0            x86_64  ...  191010   15     39     20
# 16           1.1.0            x86_64  ...  191010   15     39     30
# 17           1.1.0            x86_64  ...  191010   15     39     22
# 18           1.1.0            x86_64  ...  191010   15     39     32
# 19           1.1.0            x86_64  ...  191010   15     39     33
# 20           1.1.0            x86_64  ...  191010   15     39     34
# 21           1.1.0            x86_64  ...  191010   15     39     35
# 22           1.1.0            x86_64  ...  191010   15     39     36
# 23           1.1.0            x86_64  ...  191010   15     39     37
# 24           1.1.0            x86_64  ...  191010   15     39     38
# 25           1.1.0            x86_64  ...  191010   15     39     41
# 26           1.1.0            x86_64  ...  191010   15     39     11
# 27           1.1.0            x86_64  ...  191010   15     39     12
# 28           1.1.0            x86_64  ...  191010   15     39     13
# 29           1.1.0            x86_64  ...  191010   15     39     14
# ...            ...               ...  ...     ...  ...    ...    ...
# 298788       1.1.0            x86_64  ...  191022   16     19     15
# 298789       1.1.0            x86_64  ...  191022   16     19     17
# 298790       1.1.0            x86_64  ...  191022   16     19     18
# 298791       1.1.0            x86_64  ...  191022   16     19     19
# 298792       1.1.0            x86_64  ...  191022   16     19     20
# 298793       1.1.0            x86_64  ...  191022   16     19     21
# 298794       1.1.0            x86_64  ...  191022   16     19     22
# 298795       1.1.0            x86_64  ...  191022   16     19     23
# 298796       1.1.0            x86_64  ...  191022   16     19     24
# 298797       1.1.0            x86_64  ...  191022   16     19     25
# 298798       1.1.0            x86_64  ...  191022   16     21     14
# 298799       1.1.0            x86_64  ...  191022   16     21     15
# 298800       1.1.0            x86_64  ...  191022   16     21     16
# 298801       1.1.0            x86_64  ...  191022   16     21     17
# 298802       1.1.0            x86_64  ...  191022   16     21     18
# 298803       1.1.0            x86_64  ...  191022   16     21     19
# 298804       1.1.0            x86_64  ...  191022   16     21     21
# 298805       1.1.0            x86_64  ...  191022   16     21     22
# 298806       1.1.0            x86_64  ...  191022   16     21     23
# 298807       1.1.0            x86_64  ...  191022   16     21     25
# 298808       1.1.0            x86_64  ...  191022   16     21     24
# 298809       1.1.0            x86_64  ...  191022   16     21     26
# 298810       1.1.0            x86_64  ...  191022   16     21     27
# 298811       1.1.0            x86_64  ...  191022   16     21     28
# 298812       1.1.0            x86_64  ...  191022   16     21     29
# 298813       1.1.0            x86_64  ...  191022   16     21     30
# 298814       1.1.0            x86_64  ...  191022   16     21     32
# 298815       1.1.0            x86_64  ...  191022   16     21     31
# 298816       1.1.0            x86_64  ...  191022   16     21     33
# 298817       1.1.0            x86_64  ...  191022   16     21     35
#
#        session_id                                   message1    event  \
# 0           17507  rapierapi@10.3.8.9 as anonymous on rapier  connect
# 1           17510  rapierapi@10.3.8.9 as anonymous on rapier  connect
# 2           17511  rapierapi@10.3.8.9 as anonymous on rapier  connect
# 3           17512  rapierapi@10.3.8.9 as anonymous on rapier  connect
# 4           17515  rapierapi@10.3.8.9 as anonymous on rapier  connect
# 5           17517          zabbix@localhost as anonymous on   connect
# 6           17522          zabbix@localhost as anonymous on   connect
# 7           17276  rapierapi@10.3.8.9 as anonymous on rapier  connect
# 8           17280  rapierapi@10.3.8.9 as anonymous on rapier  connect
# 9           17283  rapierapi@10.3.8.9 as anonymous on rapier  connect
# 10          17284  rapierapi@10.3.8.9 as anonymous on rapier  connect
# 11          17279  rapierapi@10.3.8.9 as anonymous on rapier  connect
# 12          17443          zabbix@localhost as anonymous on   connect
# 13          17445  rapierapi@10.3.8.9 as anonymous on rapier  connect
# 14          17452          zabbix@localhost as anonymous on   connect
# 15          17433  rapierapi@10.3.8.9 as anonymous on rapier  connect
# 16          17456          zabbix@localhost as anonymous on   connect
# 17          17440          zabbix@localhost as anonymous on   connect
# 18          17459          zabbix@localhost as anonymous on   connect
# 19          17462  rapierapi@10.3.8.9 as anonymous on rapier  connect
# 20          17468  rapierapi@10.3.8.9 as anonymous on rapier  connect
# 21          17469  rapierapi@10.3.8.9 as anonymous on rapier  connect
# 22          17471  rapierapi@10.3.8.9 as anonymous on rapier  connect
# 23          17473  rapierapi@10.3.8.9 as anonymous on rapier  connect
# 24          17474  rapierapi@10.3.8.9 as anonymous on rapier  connect
# 25          17475  rapierapi@10.3.8.9 as anonymous on rapier  connect
# 26          17404          zabbix@localhost as anonymous on   connect
# 27          17405          zabbix@localhost as anonymous on   connect
# 28          17406          zabbix@localhost as anonymous on   connect
# 29          17408  rapierapi@10.3.8.9 as anonymous on rapier  connect
# ...           ...                                        ...      ...
# 298788     280723          zabbix@localhost as anonymous on   connect
# 298789     280728          zabbix@localhost as anonymous on   connect
# 298790     280730          zabbix@localhost as anonymous on   connect
# 298791     280733          zabbix@localhost as anonymous on   connect
# 298792     280735          zabbix@localhost as anonymous on   connect
# 298793     280737          zabbix@localhost as anonymous on   connect
# 298794     280739          zabbix@localhost as anonymous on   connect
# 298795     280741          zabbix@localhost as anonymous on   connect
# 298796     280743          zabbix@localhost as anonymous on   connect
# 298797     280745          zabbix@localhost as anonymous on   connect
# 298798     280811          zabbix@localhost as anonymous on   connect
# 298799     280813          zabbix@localhost as anonymous on   connect
# 298800     280815          zabbix@localhost as anonymous on   connect
# 298801     280817          zabbix@localhost as anonymous on   connect
# 298802     280820          zabbix@localhost as anonymous on   connect
# 298803     280822          zabbix@localhost as anonymous on   connect
# 298804     280827          zabbix@localhost as anonymous on   connect
# 298805     280829          zabbix@localhost as anonymous on   connect
# 298806     280831          zabbix@localhost as anonymous on   connect
# 298807     280835          zabbix@localhost as anonymous on   connect
# 298808     280833          zabbix@localhost as anonymous on   connect
# 298809     280837          zabbix@localhost as anonymous on   connect
# 298810     280838          zabbix@localhost as anonymous on   connect
# 298811     280839          zabbix@localhost as anonymous on   connect
# 298812     280840          zabbix@localhost as anonymous on   connect
# 298813     280841          zabbix@localhost as anonymous on   connect
# 298814     280843  rapierapi@10.3.8.9 as anonymous on rapier  connect
# 298815     280842          zabbix@localhost as anonymous on   connect
# 298816     280844          zabbix@localhost as anonymous on   connect
# 298817     280846  rapierapi@10.3.8.9 as anonymous on rapier  connect
#
#              user       from login_status
# 0       rapierapi   10.3.8.9   successful
# 1       rapierapi   10.3.8.9   successful
# 2       rapierapi   10.3.8.9   successful
# 3       rapierapi   10.3.8.9   successful
# 4       rapierapi   10.3.8.9   successful
# 5          zabbix  localhost   successful
# 6          zabbix  localhost   successful
# 7       rapierapi   10.3.8.9   successful
# 8       rapierapi   10.3.8.9   successful
# 9       rapierapi   10.3.8.9   successful
# 10      rapierapi   10.3.8.9   successful
# 11      rapierapi   10.3.8.9   successful
# 12         zabbix  localhost   successful
# 13      rapierapi   10.3.8.9   successful
# 14         zabbix  localhost   successful
# 15      rapierapi   10.3.8.9   successful
# 16         zabbix  localhost   successful
# 17         zabbix  localhost   successful
# 18         zabbix  localhost   successful
# 19      rapierapi   10.3.8.9   successful
# 20      rapierapi   10.3.8.9   successful
# 21      rapierapi   10.3.8.9   successful
# 22      rapierapi   10.3.8.9   successful
# 23      rapierapi   10.3.8.9   successful
# 24      rapierapi   10.3.8.9   successful
# 25      rapierapi   10.3.8.9   successful
# 26         zabbix  localhost   successful
# 27         zabbix  localhost   successful
# 28         zabbix  localhost   successful
# 29      rapierapi   10.3.8.9   successful
# ...           ...        ...          ...
# 298788     zabbix  localhost   successful
# 298789     zabbix  localhost   successful
# 298790     zabbix  localhost   successful
# 298791     zabbix  localhost   successful
# 298792     zabbix  localhost   successful
# 298793     zabbix  localhost   successful
# 298794     zabbix  localhost   successful
# 298795     zabbix  localhost   successful
# 298796     zabbix  localhost   successful
# 298797     zabbix  localhost   successful
# 298798     zabbix  localhost   successful
# 298799     zabbix  localhost   successful
# 298800     zabbix  localhost   successful
# 298801     zabbix  localhost   successful
# 298802     zabbix  localhost   successful
# 298803     zabbix  localhost   successful
# 298804     zabbix  localhost   successful
# 298805     zabbix  localhost   successful
# 298806     zabbix  localhost   successful
# 298807     zabbix  localhost   successful
# 298808     zabbix  localhost   successful
# 298809     zabbix  localhost   successful
# 298810     zabbix  localhost   successful
# 298811     zabbix  localhost   successful
# 298812     zabbix  localhost   successful
# 298813     zabbix  localhost   successful
# 298814  rapierapi   10.3.8.9   successful
# 298815     zabbix  localhost   successful
# 298816     zabbix  localhost   successful
# 298817  rapierapi   10.3.8.9   successful
#
# [298818 rows x 35 columns]

# %%
df_groupby_user_time = pd.DataFrame({'count_per_user' : flat_result.loc[flat_result['event'] == 'connect'].groupby(['user','date', 'hour', 'minute']).size()}).reset_index()
df_groupby_time = pd.DataFrame({'count_per_time' : flat_result.loc[flat_result['event'] == 'connect'].groupby(['date', 'hour', 'minute']).size()}).reset_index()
df_groupby_user_time_failed = pd.DataFrame({'count_failed_per_user' : flat_result.loc[flat_result['event'] == 'connect'].groupby(['user','date', 'hour', 'minute', 'login_status']).size()}).reset_index()
df_groupby_time_failed = pd.DataFrame({'count_failed_per_time' : flat_result.loc[flat_result['event'] == 'connect'].groupby(['date', 'hour', 'minute', 'login_status']).size()}).reset_index()

# %%
df_groupby_user_time_failed.count()
# Out:
# user                     18457
# date                     18457
# hour                     18457
# minute                   18457
# login_status             18457
# count_failed_per_user    18457
# dtype: int64

# %%
for index, row in df_groupby_time.iterrows():
    df_groupby_user_time.loc[(df_groupby_user_time['date'] == row['date']) &
                            (df_groupby_user_time['hour'] == row['hour']) &
                            (df_groupby_user_time['minute'] == row['minute']), 'count_per_time'] = row['count_per_time']

# %%
for index, row in df_groupby_time_failed.iterrows():
    df_groupby_user_time_failed.loc[(df_groupby_user_time_failed['date'] == row['date']) &
                            (df_groupby_user_time_failed['hour'] == row['hour']) &
                            (df_groupby_user_time_failed['minute'] == row['minute']) &
                            (df_groupby_user_time_failed['login_status'] == row['login_status']), 'count_failed_per_time'] = row['count_failed_per_time']

# %%
for index, row in df_groupby_user_time.iterrows():
    flat_result.loc[(flat_result['user'] == row['user']) &
                    (flat_result['date'] == row['date']) &
                    (flat_result['hour'] == row['hour']) &
                    (flat_result['minute'] == row['minute']), 'count_per_time'] = row['count_per_time']
    flat_result.loc[(flat_result['user'] == row['user']) &
                    (flat_result['date'] == row['date']) &
                    (flat_result['hour'] == row['hour']) &
                    (flat_result['minute'] == row['minute']) , 'count_per_user'] = row['count_per_user']

# %%
for index, row in df_groupby_user_time_failed.loc[df_groupby_user_time_failed['login_status'] == 'failed'].iterrows():
    flat_result.loc[(flat_result['user'] == row['user']) &
                    (flat_result['date'] == row['date']) &
                    (flat_result['hour'] == row['hour']) &
                    (flat_result['minute'] == row['minute']) , 'count_failed_per_time'] = row['count_failed_per_time']
    flat_result.loc[(flat_result['user'] == row['user']) &
                    (flat_result['date'] == row['date']) &
                    (flat_result['hour'] == row['hour']) &
                    (flat_result['minute'] == row['minute']) , 'count_failed_per_user'] = row['count_failed_per_user']

flat_result['count_failed_per_time'].fillna(0, inplace=True) 
flat_result['count_failed_per_user'].fillna(0, inplace=True)

# %%
# flat_result
flat_result.to_csv(r'data/scan_filebeat_2019-10-22_afterpreprocessed_1.csv')

# %%
# flat_result.loc[(flat_result['minute'] == 33) & (flat_result['second'] == 54) & (flat_result['login_status'] == 'failed')]
# flat_result.loc[flat_result['count_failed_per_user'] == 0, 'count_failed_per_user']

# %%
# flat_result.loc[flat_result['event'] == 'other']
# flat_result.loc[flat_result['event'] == 'connect'].groupby(['user','date', 'hour', 'minute'])['event'].value_counts()
# flat_result.loc[flat_result['event'] == 'connect'].groupby(['user','date', 'hour', 'minute']).count()
# df_groupby_user_time_failed
# df_groupby_time_failed

# %%
# flat_result['session_id'].value_counts()
# flat_result.loc[flat_result['session_id'] == '15696']
# flat_result.loc[flat_result['event'] == 'connect']
# flat_result

# %%
flat_result.loc[(flat_result['_source.message'].str.find('Connect') < 0) & 
                (flat_result['_source.message'].str.find('select') < 0), 'message1']

# %%
# flat_result.loc[flat_result['_source.message'].str.find('Connect') >= 0, '_source.message']
flat_result.loc[flat_result['_source.message'].str.find('Connect') >= 0, '_source.message']

# %%
#Access denied for user 'user'@'10.3.255.61' (using password: YES)
#sysdba@10.3.255.61 as anonymous on mypassword
# flat_result.loc[flat_result['message1'].str.find("Access denied") < 0, 'message1']
flat_result.head()

# %%
df_counts = pd.DataFrame(data = flat_result['message1'].value_counts()) 
df_counts.reset_index(level=0, inplace=True) 
df_counts.info()
df_counts
# flat_result['message_label'].value_counts()

# %%
df_counts.plot.bar(x='index', y='message1', rot=0, figsize=(20,15))

# %%
flat_result['message1'].count()

# %%
flat_result.describe()

# %%
message_encoder = LabelEncoder()
message_label = message_encoder.fit_transform(flat_result['message1'])

flat_result['message_label'] = message_label

flat_result['message_label'].hist(bins=20, figsize=(20,15))
plt.show()

# %% [markdown]
# ## machine learning model

# %%
from sklearn.feature_selection import mutual_info_classif
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder

# %%
df_model1.columns
# credential_spray_detection_train_x.columns
# flat_result.columns
# Out:
# Index(['hour', 'minute', 'second', 'session_id', 'event', 'user', 'from',
#        'login_status', 'count_per_time', 'count_per_user',
#        'count_failed_per_time', 'count_failed_per_user', 'event_code',
#        'user_code', 'from_code', 'login_status_code'],
#       dtype='object')

# %%
# df_model1 = flat_result.loc[flat_result['event'] == 'connect'].iloc[:, [6, 7, 8, 11, 12, 13, 14, 15, 16, 17, 18]]
df_model1 = flat_result.loc[flat_result['event'] == 'connect'].iloc[:, [25, 26, 27, 28, 30, 31, 32, 33, 34, 35, 36, 37]]
# df_model1.drop_duplicates(inplace=True)
# df_model1.reset_index(inplace=True)
df_model1.reset_index(inplace=True)
df_model1 = df_model1.iloc[:, 1:]

# %%
event_encoder = LabelEncoder()
event_encoder_result = event_encoder.fit_transform(df_model1['event'])
df_model1['event_code'] = event_encoder_result

# %%
user_encoder = LabelEncoder()
user_encoder_result = user_encoder.fit_transform(df_model1['user'])
df_model1['user_code'] = user_encoder_result

# %%
from_encoder = LabelEncoder()
from_encoder_result = from_encoder.fit_transform(df_model1['from'])
df_model1['from_code'] = from_encoder_result

# %%
login_status_encoder = LabelEncoder()
login_status_encoder_result = login_status_encoder.fit_transform(df_model1['login_status'])
df_model1['login_status_code'] = login_status_encoder_result

# %%
credential_spray_detection_train_x = df_model1.iloc[:, [0, 1, 9, 10, 11, 13, 14]]
credential_spray_detection_train_y = df_model1.iloc[:, [8]]

# %%
credential_spray_detection_train_x
# credential_spray_detection_train_y
# df_model1
# df_model1
# Out:
#        hour minute  count_per_user  count_failed_per_time  \
# 0        15     40            25.0                    0.0
# 1        15     40            25.0                    0.0
# 2        15     40            25.0                    0.0
# 3        15     40            25.0                    0.0
# 4        15     40            25.0                    0.0
# 5        15     40             8.0                    0.0
# 6        15     40             8.0                    0.0
# 7        15     37             1.0                    0.0
# 8        15     38            31.0                    0.0
# 9        15     38            31.0                    0.0
# 10       15     38            31.0                    0.0
# 11       15     38            31.0                    0.0
# 12       15     39            13.0                    0.0
# 13       15     39            24.0                    0.0
# 14       15     39            13.0                    0.0
# 15       15     39            24.0                    0.0
# 16       15     39            13.0                    0.0
# 17       15     39            13.0                    0.0
# 18       15     39            13.0                    0.0
# 19       15     39            24.0                    0.0
# 20       15     39            24.0                    0.0
# 21       15     39            24.0                    0.0
# 22       15     39            24.0                    0.0
# 23       15     39            24.0                    0.0
# 24       15     39            24.0                    0.0
# 25       15     39            24.0                    0.0
# 26       15     39            13.0                    0.0
# 27       15     39            13.0                    0.0
# 28       15     39            13.0                    0.0
# 29       15     39            24.0                    0.0
# ...     ...    ...             ...                    ...
# 298702   16     19            21.0                    0.0
# 298703   16     19            21.0                    0.0
# 298704   16     19            21.0                    0.0
# 298705   16     19            21.0                    0.0
# 298706   16     19            21.0                    0.0
# 298707   16     19            21.0                    0.0
# 298708   16     19            21.0                    0.0
# 298709   16     19            21.0                    0.0
# 298710   16     19            21.0                    0.0
# 298711   16     19            21.0                    0.0
# 298712   16     21            21.0                    0.0
# 298713   16     21            21.0                    0.0
# 298714   16     21            21.0                    0.0
# 298715   16     21            21.0                    0.0
# 298716   16     21            21.0                    0.0
# 298717   16     21            21.0                    0.0
# 298718   16     21            21.0                    0.0
# 298719   16     21            21.0                    0.0
# 298720   16     21            21.0                    0.0
# 298721   16     21            21.0                    0.0
# 298722   16     21            21.0                    0.0
# 298723   16     21            21.0                    0.0
# 298724   16     21            21.0                    0.0
# 298725   16     21            21.0                    0.0
# 298726   16     21            21.0                    0.0
# 298727   16     21            21.0                    0.0
# 298728   16     21             6.0                    0.0
# 298729   16     21            21.0                    0.0
# 298730   16     21            21.0                    0.0
# 298731   16     21             6.0                    0.0
#
#         count_failed_per_user  user_code  from_code
# 0                         0.0          3          5
# 1                         0.0          3          5
# 2                         0.0          3          5
# 3                         0.0          3          5
# 4                         0.0          3          5
# 5                         0.0          5          7
# 6                         0.0          5          7
# 7                         0.0          3          5
# 8                         0.0          3          5
# 9                         0.0          3          5
# 10                        0.0          3          5
# 11                        0.0          3          5
# 12                        0.0          5          7
# 13                        0.0          3          5
# 14                        0.0          5          7
# 15                        0.0          3          5
# 16                        0.0          5          7
# 17                        0.0          5          7
# 18                        0.0          5          7
# 19                        0.0          3          5
# 20                        0.0          3          5
# 21                        0.0          3          5
# 22                        0.0          3          5
# 23                        0.0          3          5
# 24                        0.0          3          5
# 25                        0.0          3          5
# 26                        0.0          5          7
# 27                        0.0          5          7
# 28                        0.0          5          7
# 29                        0.0          3          5
# ...                       ...        ...        ...
# 298702                    0.0          5          7
# 298703                    0.0          5          7
# 298704                    0.0          5          7
# 298705                    0.0          5          7
# 298706                    0.0          5          7
# 298707                    0.0          5          7
# 298708                    0.0          5          7
# 298709                    0.0          5          7
# 298710                    0.0          5          7
# 298711                    0.0          5          7
# 298712                    0.0          5          7
# 298713                    0.0          5          7
# 298714                    0.0          5          7
# 298715                    0.0          5          7
# 298716                    0.0          5          7
# 298717                    0.0          5          7
# 298718                    0.0          5          7
# 298719                    0.0          5          7
# 298720                    0.0          5          7
# 298721                    0.0          5          7
# 298722                    0.0          5          7
# 298723                    0.0          5          7
# 298724                    0.0          5          7
# 298725                    0.0          5          7
# 298726                    0.0          5          7
# 298727                    0.0          5          7
# 298728                    0.0          3          5
# 298729                    0.0          5          7
# 298730                    0.0          5          7
# 298731                    0.0          3          5
#
# [298732 rows x 7 columns]

# %%
train_features, test_features, train_labels, test_labels = train_test_split(credential_spray_detection_train_x, 
                                                                            credential_spray_detection_train_y,
                                                                           test_size=0.2,
                                                                           random_state = 42)

# %%
# test1 = pd.concat(test_features, test_labels)
test_features

# %%
test_features['prediction'] = prediction1
test_features['label'] = test_labels
test_features.to_csv(r'data/prediction_minute_3.csv')

# %%
test_labels

# %%
credential_spray_rf_class = RandomForestClassifier(max_depth=12, n_estimators=20, max_features=7)

# %%
credential_spray_rf_class.fit(train_features, train_labels)
# Out:
# /home/febriantoe/anaconda3/envs/environment1/lib/python3.7/site-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=12, max_features=7, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=20,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
prediction1 = credential_spray_rf_class.predict(test_features)
training_score = credential_spray_rf_class.score(test_features, test_labels)
training_score
# Out:
# 0.46179724504996067

# %%
# df_model1.head()
# credential_spray_detection_train_x
test_features['prediction'] =prediction1
test_features['label'] = test_labels
test_features.to_csv(r'data/prediction_minute_3.csv')
# Out:
# /home/febriantoe/anaconda3/envs/environment1/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/febriantoe/anaconda3/envs/environment1/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
df1 = prediction

# %%
# flat_result.loc[flat_result['event'] == 'connect'].iloc[:, [6, 7, 8, 11, 12, 13, 14, 15, 16, 17, 18]]
# df_model1['event_code'].value_counts()

# %%
# flat_result.loc[(flat_result['event'] == 'connect') & (flat_result['login_status'] != 'failed')]
# flat_result.loc[flat_result['event'] == 'connect', 'session_id'].map(lambda x: flat_result.loc[(flat_result['session_id'] == x) & (flat_result['login_status'] == 'failed'), 'login_status'])

# 8066

# 18800
# 18809

# df_model1.iloc[4744:4775]
# df_model1.iloc[475]

flat_result.loc[(flat_result['message'].str.find("Access denied") >= 0) & (flat_result['hour'] == 8) , 'minute' ]
# flat_result.columns

# df_model1.loc[df_model1['count_per_time'] == 9804]
# df_model1.loc[df_model1['count_per_time'] == 9804]

# %%
test_features['diff'] = test_features['label'] - test_features['prediction']
# Out:
# /home/febriantoe/anaconda3/envs/environment1/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
test_features['diff'].describe()
# Out:
# count    59747.000000
# mean         0.188478
# std          3.294778
# min        -23.000000
# 25%         -1.000000
# 50%          0.000000
# 75%          1.000000
# max         19.000000
# Name: diff, dtype: float64

# %%
test_features['diff'].hist(bins=20, figsize=(20,15))
